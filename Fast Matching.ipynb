# %%
# %load_ext autoreload
# %autoreload 2

# %%
import figures
import itertools
import fastmatch
import matchutil
from imaging import open_img
from cache import Metric_Cache, Grid_Cache
import cProfile

# %%
query_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG'
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-005_08-35-43_0.JPG" # for 5
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-015_08-36-10_0.JPG" # for 15
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG' # for 25
target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-030_08-36-46_0.JPG' # For 30
query_cache = Metric_Cache(query_path)
target_img = open_img(target_path)
query_img = open_img(query_path)

# %%
log = []
matches = None
options = {"evaluate_verbose" : True,
            "thumb_strategy" : lambda n : 1.0,
            "neighbor_strategy" : lambda n : 1.2,
            "grid_size" : (90, 90),
            "grid_margin" : 25,
            "radius" : 50,
            "dist_threshold" : 50,
            "depth_first" : True,
            "thumb_size" : (300, 300),
            "log" : log}
cProfile.run('matches = list(fastmatch.match(query_cache, target_img, options = options)(0.9))')
#atches = fastmatch.match(query_cache, target_img, options = options)(0.9)
#print(sorted(zip(*matches)[1]))
print("length of log: %i" % len(log))
print("length of matches: %i" % len(matches))
# Out:
#          180541 function calls in 1.657 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-17-a8eed8bca671>:4(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-17-a8eed8bca671>:5(<lambda>)
#         1    0.004    0.004    1.657    1.657 <string>:1(<module>)
#         2    0.000    0.000    0.028    0.014 Image.py:1395(resize)
#         2    0.000    0.000    0.028    0.014 Image.py:1637(thumbnail)
#         2    0.000    0.000    0.009    0.005 Image.py:1862(new)
#         2    0.000    0.000    0.023    0.012 Image.py:1890(frombytes)
#         2    0.000    0.000    0.023    0.012 Image.py:1938(frombuffer)
#         2    0.000    0.000    0.023    0.012 Image.py:1999(fromarray)
#         1    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         2    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         1    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#         6    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#         4    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         2    0.000    0.000    0.000    0.000 Image.py:528(__getattr__)
#         1    0.000    0.000    0.000    0.000 Image.py:539(tobytes)
#         2    0.000    0.000    0.014    0.007 Image.py:603(frombytes)
#         5    0.000    0.000    0.000    0.000 Image.py:637(load)
#         2    0.000    0.000    0.000    0.000 Image.py:895(draft)
#       937    0.001    0.000    0.011    0.000 _methods.py:23(_sum)
#       354    0.001    0.000    0.004    0.000 _methods.py:35(_all)
#         2    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#       937    0.001    0.000    0.002    0.000 base.py:702(isspmatrix)
#       179    0.019    0.000    0.416    0.002 cache.pyx:107(cache_block)
#      4312    0.027    0.000    0.039    0.000 cache.pyx:136(get_neighbor)
#     14550    0.011    0.000    0.012    0.000 cache.pyx:213(block)
#       937    0.001    0.000    0.001    0.000 cache.pyx:217(cell)
#       358    0.000    0.000    0.000    0.000 cache.pyx:221(frame)
#       179    0.000    0.000    0.392    0.002 cache.pyx:231(get_cell_data)
#     12660    0.008    0.000    0.009    0.000 cache.pyx:237(center)
#        39    0.003    0.000    0.392    0.010 cache.pyx:246(cache)
#     49983    0.004    0.000    0.004    0.000 cache.pyx:27(__init__)
#       937    0.202    0.000    0.250    0.000 cache.pyx:309(get)
#         3    0.000    0.000    0.000    0.000 cache.pyx:32(__init__)
#     31522    0.007    0.000    0.007    0.000 cache.pyx:40(__init__)
#       358    0.000    0.000    0.000    0.000 cache.pyx:50(__init__)
#         1    0.000    0.000    0.000    0.000 cache.pyx:73(__init__)
#       937    0.002    0.000    0.420    0.000 cache.pyx:89(get)
#     12676    0.082    0.000    0.302    0.000 fastmatch.pyx:104(is_new_match)
#     12497    0.191    0.000    0.191    0.000 fastmatch.pyx:122(above_dist_threshold)
#         1    0.000    0.000    0.082    0.082 fastmatch.pyx:132(match_thumbs)
#       937    0.025    0.000    1.085    0.001 fastmatch.pyx:171(match_position)
#       933    0.013    0.000    0.013    0.000 fastmatch.pyx:202(get_ratios)
#       933    0.019    0.000    0.019    0.000 fastmatch.pyx:205(get_positions)
#       932    0.004    0.000    0.004    0.000 fastmatch.pyx:208(get_indices)
#       933    0.355    0.000    0.355    0.000 fastmatch.pyx:211(do_match)
#       937    0.018    0.000    0.018    0.000 fastmatch.pyx:218(log_round)
#         1    0.000    0.000    0.082    0.082 fastmatch.pyx:32(match)
#         1    0.000    0.000    1.571    1.571 fastmatch.pyx:51(get_matches)
#         1    0.124    0.124    1.571    1.571 fastmatch.pyx:60(do_iter)
#       937    0.001    0.000    0.003    0.000 fromnumeric.py:1281(ravel)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:792(argsort)
#       937    0.004    0.000    0.014    0.000 function_base.py:3503(append)
#         2    0.000    0.000    0.023    0.012 imaging.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         2    0.000    0.000    0.023    0.012 imaging.py:43(from_array)
#         3    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         1    0.000    0.000    0.028    0.028 imaging.py:52(scale)
#         2    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         1    0.000    0.000    0.042    0.042 imaging.py:80(get_thumbnail)
#         1    0.000    0.000    0.010    0.010 imaging.py:84(get_size)
#        40    0.000    0.000    0.418    0.010 matchutil.py:22(get_features)
#      2811    0.002    0.000    0.009    0.000 numeric.py:392(asarray)
#      2811    0.003    0.000    0.007    0.000 numeric.py:462(asanyarray)
#       937    0.006    0.000    0.009    0.000 shape_base.py:60(atleast_2d)
#       937    0.003    0.000    0.007    0.000 shape_base.py:8(atleast_1d)
#       937    0.006    0.000    0.018    0.000 validation.py:23(_assert_all_finite)
#       937    0.004    0.000    0.037    0.000 validation.py:86(array2d)
#         2    0.009    0.005    0.009    0.005 {PIL._imaging.fill}
#         2    0.000    0.000    0.000    0.000 {PIL._imaging.raw_decoder}
#         1    0.000    0.000    0.000    0.000 {PIL._imaging.raw_encoder}
#        40    0.000    0.000    0.000    0.000 {cv2.SIFT}
#         1    0.000    0.000    0.082    0.082 {fastmatch.match}
#         3    0.000    0.000    0.000    0.000 {getattr}
#       948    0.001    0.000    0.001    0.000 {isinstance}
#      4694    0.001    0.000    0.001    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {map}
#         3    0.000    0.000    0.000    0.000 {max}
#      1878    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.014    0.007    0.014    0.007 {method 'decode' of 'ImagingDecoder' objects}
#        40    0.418    0.010    0.418    0.010 {method 'detectAndCompute' of 'cv2.Feature2D' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'encode' of 'ImagingEncoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#      1874    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1291    0.013    0.000    0.013    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       937    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'resize' of 'ImagingCore' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingDecoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#         1    0.027    0.027    0.027    0.027 {method 'stretch' of 'ImagingCore' objects}
#       937    0.001    0.000    0.012    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      5623    0.011    0.000    0.011    0.000 {numpy.core.multiarray.array}
#       937    0.004    0.000    0.004    0.000 {numpy.core.multiarray.concatenate}
#
#
# length of log: 937
# length of matches: 130

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 140)#, filename= "frame")

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 120)#, filename= "frame")

# %%
t = numpy.empty(0)
p = numpy.array([14, 54])
ps = numpy.append(t,p)
ps = numpy.append(ps,p)
#ps = numpy.append(ps, p.T, axis=0)
ps.reshape((ps.size / 2, 2))
# Out:
# array([[ 14.,  54.],
#        [ 14.,  54.]])

# %%
# %timeit numpy.array([1,2,3,4])
# Out:
# 1000000 loops, best of 3: 1.51 µs per loop
