# %%
# %load_ext autoreload
# %autoreload 2

# %%
import figures
import itertools
import fastmatch_alt
import fastmatch
import matchutil
from imaging import open_img
from cache import Feature_Cache, Metric_Cache, Grid_Cache
import cProfile

# %%
query_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG'
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-005_08-35-43_0.JPG" # for 5
target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-015_08-36-10_0.JPG" # for 15
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG' # for 25
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-030_08-36-46_0.JPG' # For 30
#query_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-000_11-58-32_0.JPG'
#target_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-005_11-59-06_0.JPG'
baseline_cache = Feature_Cache(query_path)
query_cache = Metric_Cache(query_path)
target_img = open_img(target_path)
query_img = open_img(query_path)

# %%
log = []
matches = None
options = {"evaluate_verbose" : True,
            "thumb_strategy" : lambda n : 1.0,
            "neighbor_strategy" : lambda n : 0.9,
            "grid_size" : (90, 90),
            "grid_margin" : 25,
            "radius" : 50,
            "dist_threshold" : 50,
            "depth_first" : True,
            "thumb_size" : (300, 300),
            "log" : log,
            "baseline_cache" : baseline_cache }
cProfile.run('matches = list(fastmatch.match(query_cache, target_img, options = options)(0.9))')
#cProfile.run('matches = list(fastmatch_alt.match(query_cache, target_img, options = options)(0.9))')
#matches = fastmatch_alt.match(query_cache, target_img, options = options)(0.9)
#fastmatch_alt.match(query_img, target_img, baseline_cache, options = options)(0.9)
#print(sorted(zip(*matches)[1]))
print("length of log: %i" % len(log))
print("length of matches: %i" % len(matches))
# Out:
#          7477 function calls (7476 primitive calls) in 0.267 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000    0.176    0.176 <string>:1(<module>)
#         2    0.000    0.000    0.029    0.015 Image.py:1395(resize)
#         2    0.000    0.000    0.029    0.015 Image.py:1637(thumbnail)
#         2    0.000    0.000    0.016    0.008 Image.py:1862(new)
#         2    0.000    0.000    0.029    0.014 Image.py:1890(frombytes)
#         2    0.000    0.000    0.029    0.014 Image.py:1938(frombuffer)
#         2    0.000    0.000    0.029    0.015 Image.py:1999(fromarray)
#         1    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         2    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         1    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#         6    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#         4    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         2    0.000    0.000    0.000    0.000 Image.py:528(__getattr__)
#         1    0.000    0.000    0.000    0.000 Image.py:539(tobytes)
#         2    0.000    0.000    0.013    0.007 Image.py:603(frombytes)
#         5    0.000    0.000    0.000    0.000 Image.py:637(load)
#         2    0.000    0.000    0.000    0.000 Image.py:895(draft)
#        70    0.000    0.000    0.001    0.000 _methods.py:23(_sum)
#        94    0.000    0.000    0.001    0.000 _methods.py:35(_all)
#         2    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#        70    0.000    0.000    0.000    0.000 base.py:702(isspmatrix)
#        47    0.004    0.000    0.138    0.003 cache.pyx:102(cache_block)
#       177    0.001    0.000    0.001    0.000 cache.pyx:133(get_neighbor)
#       519    0.000    0.000    0.000    0.000 cache.pyx:185(square_to_block)
#       177    0.000    0.000    0.000    0.000 cache.pyx:195(neighbors_square)
#       672    0.000    0.000    0.000    0.000 cache.pyx:207(block)
#        70    0.000    0.000    0.000    0.000 cache.pyx:211(cell)
#        94    0.000    0.000    0.000    0.000 cache.pyx:215(frame)
#        47    0.000    0.000    0.132    0.003 cache.pyx:225(get_cell_data)
#       519    0.000    0.000    0.000    0.000 cache.pyx:231(center)
#        14    0.001    0.000    0.132    0.009 cache.pyx:240(cache)
#         3    0.000    0.000    0.000    0.000 cache.pyx:28(__init__)
#        70    0.012    0.000    0.016    0.000 cache.pyx:304(get)
#      1368    0.000    0.000    0.000    0.000 cache.pyx:36(__init__)
#        94    0.000    0.000    0.000    0.000 cache.pyx:46(__init__)
#         1    0.000    0.000    0.000    0.000 cache.pyx:69(__init__)
#        70    0.000    0.000    0.138    0.002 cache.pyx:85(get)
#       532    0.001    0.000    0.001    0.000 fastmatch.pyx:111(is_new_match)
#       485    0.000    0.000    0.000    0.000 fastmatch.pyx:124(above_dist_threshold)
#         1    0.000    0.000    0.091    0.091 fastmatch.pyx:135(match_thumbs)
#        70    0.002    0.000    0.168    0.002 fastmatch.pyx:174(match_position)
#        68    0.001    0.000    0.001    0.000 fastmatch.pyx:204(get_ratios)
#        68    0.001    0.000    0.001    0.000 fastmatch.pyx:207(get_positions)
#        68    0.010    0.000    0.010    0.000 fastmatch.pyx:210(do_match)
#        70    0.001    0.000    0.001    0.000 fastmatch.pyx:217(log_round)
#         1    0.000    0.000    0.091    0.091 fastmatch.pyx:32(match)
#         1    0.000    0.000    0.175    0.175 fastmatch.pyx:51(get_matches)
#         1    0.003    0.003    0.175    0.175 fastmatch.pyx:58(do_iter)
#        70    0.001    0.000    0.001    0.000 fastmatch.pyx:92(add_matches)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:792(argsort)
#         2    0.000    0.000    0.029    0.015 imaging.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         2    0.000    0.000    0.029    0.015 imaging.py:43(from_array)
#         3    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         1    0.000    0.000    0.029    0.029 imaging.py:52(scale)
#         2    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         1    0.000    0.000    0.048    0.048 imaging.py:80(get_thumbnail)
#         1    0.000    0.000    0.011    0.011 imaging.py:84(get_size)
#        15    0.000    0.000    0.163    0.011 matchutil.py:23(get_features)
#       140    0.000    0.000    0.001    0.000 numeric.py:392(asarray)
#       140    0.000    0.000    0.000    0.000 numeric.py:462(asanyarray)
#        70    0.001    0.000    0.001    0.000 shape_base.py:60(atleast_2d)
#        70    0.000    0.000    0.001    0.000 shape_base.py:8(atleast_1d)
#        70    0.001    0.000    0.001    0.000 validation.py:23(_assert_all_finite)
#        70    0.000    0.000    0.003    0.000 validation.py:86(array2d)
#         2    0.016    0.008    0.016    0.008 {PIL._imaging.fill}
#         2    0.000    0.000    0.000    0.000 {PIL._imaging.raw_decoder}
#         1    0.000    0.000    0.000    0.000 {PIL._imaging.raw_encoder}
#        15    0.000    0.000    0.000    0.000 {cv2.SIFT}
#         1    0.000    0.000    0.091    0.091 {fastmatch.match}
#         3    0.000    0.000    0.000    0.000 {getattr}
#        81    0.000    0.000    0.000    0.000 {isinstance}
#       359    0.000    0.000    0.000    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {map}
#         3    0.000    0.000    0.000    0.000 {max}
#       144    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.013    0.007    0.013    0.007 {method 'decode' of 'ImagingDecoder' objects}
#        15    0.162    0.011    0.162    0.011 {method 'detectAndCompute' of 'cv2.Feature2D' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'encode' of 'ImagingEncoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#       164    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        70    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'resize' of 'ImagingCore' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingDecoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#         1    0.028    0.028    0.028    0.028 {method 'stretch' of 'ImagingCore' objects}
#        70    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       281    0.001    0.000    0.001    0.000 {numpy.core.multiarray.array}
#
#
# length of log: 70
# length of matches: 38

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 140)#, filename= "frame")

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 120, alt=True)#, filename= "frame")

# %%
t = numpy.empty(0)
p = numpy.array([14, 54])
ps = numpy.append(t,p)
ps = numpy.append(ps,p)
#ps = numpy.append(ps, p.T, axis=0)
ps.reshape((ps.size / 2, 2))
# Out:
# array([[ 14.,  54.],
#        [ 14.,  54.]])

# %%
len(numpy.array([[1,2],[3,4]]))
# Out:
# 2
