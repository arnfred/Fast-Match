# %%
# %load_ext autoreload
# %autoreload 2

# %%
import figures
import itertools
import fastmatch
import matchutil
from imaging import open_img
from cache import Metric_Cache, Grid_Cache
import cProfile

# %%
#query_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG'
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-005_08-35-43_0.JPG" # for 5
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-015_08-36-10_0.JPG" # for 15
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG' # for 25
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-030_08-36-46_0.JPG' # For 30
query_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-000_11-58-32_0.JPG'
target_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-005_11-59-06_0.JPG'
query_cache = Metric_Cache(query_path)
target_img = open_img(target_path)
query_img = open_img(query_path)

# %%
log = []
matches = None
options = {"evaluate_verbose" : True,
            "thumb_strategy" : lambda n : 1.0,
            "neighbor_strategy" : lambda n : 0.9,
            "grid_size" : (90, 90),
            "grid_margin" : 25,
            "radius" : 50,
            "dist_threshold" : 50,
            "depth_first" : True,
            "thumb_size" : (300, 300),
            "log" : log}
cProfile.run('matches = list(fastmatch.match(query_cache, target_img, options = options)(0.9))')
#atches = fastmatch.match(query_cache, target_img, options = options)(0.9)
#print(sorted(zip(*matches)[1]))
print("length of log: %i" % len(log))
print("length of matches: %i" % len(matches))
# Out:
#          117970 function calls (117969 primitive calls) in 1.661 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.001    0.000    1.561    1.561 <string>:1(<module>)
#         2    0.000    0.000    0.032    0.016 Image.py:1395(resize)
#         2    0.000    0.000    0.032    0.016 Image.py:1637(thumbnail)
#         2    0.000    0.000    0.013    0.007 Image.py:1862(new)
#         2    0.000    0.000    0.027    0.014 Image.py:1890(frombytes)
#         2    0.000    0.000    0.027    0.014 Image.py:1938(frombuffer)
#         2    0.001    0.000    0.028    0.014 Image.py:1999(fromarray)
#         1    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         2    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         1    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#         6    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#         4    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         2    0.000    0.000    0.000    0.000 Image.py:528(__getattr__)
#         1    0.000    0.000    0.000    0.000 Image.py:539(tobytes)
#         2    0.000    0.000    0.014    0.007 Image.py:603(frombytes)
#         5    0.000    0.000    0.000    0.000 Image.py:637(load)
#         2    0.000    0.000    0.000    0.000 Image.py:895(draft)
#       622    0.001    0.000    0.008    0.000 _methods.py:23(_sum)
#       600    0.001    0.000    0.008    0.000 _methods.py:35(_all)
#         2    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#       622    0.001    0.000    0.001    0.000 base.py:702(isspmatrix)
#       300    0.046    0.000    0.770    0.003 cache.pyx:102(cache_block)
#      3893    0.010    0.000    0.020    0.000 cache.pyx:133(get_neighbor)
#     11352    0.001    0.000    0.001    0.000 cache.pyx:185(square_to_block)
#      3893    0.001    0.000    0.001    0.000 cache.pyx:195(neighbors_square)
#     12637    0.005    0.000    0.005    0.000 cache.pyx:207(block)
#       622    0.001    0.000    0.001    0.000 cache.pyx:211(cell)
#       600    0.001    0.000    0.001    0.000 cache.pyx:215(frame)
#       300    0.000    0.000    0.716    0.002 cache.pyx:225(get_cell_data)
#     11352    0.007    0.000    0.008    0.000 cache.pyx:231(center)
#        49    0.008    0.000    0.716    0.015 cache.pyx:240(cache)
#         3    0.000    0.000    0.000    0.000 cache.pyx:28(__init__)
#       622    0.160    0.000    0.195    0.000 cache.pyx:303(get)
#     27882    0.003    0.000    0.003    0.000 cache.pyx:36(__init__)
#       600    0.000    0.000    0.000    0.000 cache.pyx:46(__init__)
#         1    0.000    0.000    0.000    0.000 cache.pyx:69(__init__)
#       622    0.002    0.000    0.773    0.001 cache.pyx:85(get)
#     11393    0.014    0.000    0.024    0.000 fastmatch.pyx:114(is_new_match)
#     11093    0.005    0.000    0.005    0.000 fastmatch.pyx:127(above_dist_threshold)
#         1    0.000    0.000    0.100    0.100 fastmatch.pyx:138(match_thumbs)
#       622    0.013    0.000    1.453    0.002 fastmatch.pyx:177(match_position)
#       623    0.009    0.000    0.009    0.000 fastmatch.pyx:207(get_ratios)
#       623    0.014    0.000    0.014    0.000 fastmatch.pyx:210(get_positions)
#       623    0.452    0.001    0.452    0.001 fastmatch.pyx:213(do_match)
#       622    0.013    0.000    0.013    0.000 fastmatch.pyx:220(log_round)
#         1    0.000    0.000    0.100    0.100 fastmatch.pyx:32(match)
#         1    0.000    0.000    1.560    1.560 fastmatch.pyx:51(get_matches)
#         1    0.042    0.042    1.560    1.560 fastmatch.pyx:58(do_iter)
#       622    0.006    0.000    0.006    0.000 fastmatch.pyx:95(add_matches)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:792(argsort)
#         2    0.000    0.000    0.028    0.014 imaging.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         2    0.000    0.000    0.028    0.014 imaging.py:43(from_array)
#         3    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         1    0.000    0.000    0.032    0.032 imaging.py:52(scale)
#         2    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         1    0.000    0.000    0.045    0.045 imaging.py:80(get_thumbnail)
#         1    0.000    0.000    0.015    0.015 imaging.py:84(get_size)
#        50    0.000    0.000    0.744    0.015 matchutil.py:23(get_features)
#      1244    0.001    0.000    0.006    0.000 numeric.py:392(asarray)
#      1244    0.001    0.000    0.003    0.000 numeric.py:462(asanyarray)
#       622    0.005    0.000    0.007    0.000 shape_base.py:60(atleast_2d)
#       622    0.002    0.000    0.005    0.000 shape_base.py:8(atleast_1d)
#       622    0.004    0.000    0.013    0.000 validation.py:23(_assert_all_finite)
#       622    0.003    0.000    0.027    0.000 validation.py:86(array2d)
#         2    0.013    0.007    0.013    0.007 {PIL._imaging.fill}
#         2    0.000    0.000    0.000    0.000 {PIL._imaging.raw_decoder}
#         1    0.000    0.000    0.000    0.000 {PIL._imaging.raw_encoder}
#        50    0.000    0.000    0.000    0.000 {cv2.SIFT}
#         1    0.000    0.000    0.100    0.100 {fastmatch.match}
#         3    0.000    0.000    0.000    0.000 {getattr}
#       633    0.001    0.000    0.001    0.000 {isinstance}
#      3119    0.000    0.000    0.000    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {map}
#         3    0.000    0.000    0.000    0.000 {max}
#      1248    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.013    0.007    0.013    0.007 {method 'decode' of 'ImagingDecoder' objects}
#        50    0.744    0.015    0.744    0.015 {method 'detectAndCompute' of 'cv2.Feature2D' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'encode' of 'ImagingEncoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#      1222    0.013    0.000    0.013    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       622    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.001    0.001 {method 'resize' of 'ImagingCore' objects}
#         2    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingDecoder' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#         1    0.031    0.031    0.031    0.031 {method 'stretch' of 'ImagingCore' objects}
#       622    0.001    0.000    0.008    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      2489    0.006    0.000    0.006    0.000 {numpy.core.multiarray.array}
#
#
# length of log: 622
# length of matches: 759

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 300)#, filename= "frame")

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 120)#, filename= "frame")

# %%
t = numpy.empty(0)
p = numpy.array([14, 54])
ps = numpy.append(t,p)
ps = numpy.append(ps,p)
#ps = numpy.append(ps, p.T, axis=0)
ps.reshape((ps.size / 2, 2))
# Out:
# array([[ 14.,  54.],
#        [ 14.,  54.]])

# %%
len(numpy.array([[1,2],[3,4]]))
# Out:
# 2
