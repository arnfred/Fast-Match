# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import figures
import itertools
import fastmatch_alt
import fastmatch
import matchutil
from imaging import open_img
from cache import Feature_Cache, Metric_Cache, Grid_Cache
import cProfile

# %%
baseline_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG'
query_path = '../../Images/turntable//imageset_1/Car/Bottom/img_1-000_13-36-32_0.JPG'
target_path = '../../Images/turntable//imageset_1/Car/Bottom/img_1-020_13-37-43_0.JPG'
#query_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG'
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-005_08-35-43_0.JPG" # for 5
#target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-015_08-36-10_0.JPG" # for 15
#baseline_path = '../../Images/turntable//imageset_1/Car/Bottom/img_1-000_13-36-32_0.JPG'
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG' # for 25
#target_path = '../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-030_08-36-46_0.JPG' # For 30
query_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-000_11-58-32_0.JPG'
target_path = '../../Images/turntable//imageset_1/Motorcycle/Bottom/img_1-005_11-59-06_0.JPG'
baseline_cache = Feature_Cache(baseline_path)
query_cache = Metric_Cache(query_path)
target_img = open_img(target_path)
query_img = open_img(query_path)

# %%
log = []
matches = None
options = {"evaluate_verbose" : True,
            "thumb_tau" : 0.8,
            "neighbor_tau" : 0.8,
            "grid_size" : (90, 90),
            "grid_margin" : 25,
            "radius" : 50,
            "dist_threshold" : 50,
            "depth_first" : True,
            "thumb_size" : (300, 300),
            "log" : log,
            "baseline_cache" : baseline_cache,
            "related" : True }
#cProfile.run('matches = list(fastmatch.match(query_cache, target_img, options = options)(0.9))')
cProfile.run('matches = list(fastmatch_alt.match(query_cache, target_img, options = options)(0.9))')
#matches = fastmatch_alt.match(query_cache, target_img, options = options)(0.9)
#fastmatch_alt.match(query_img, target_img, baseline_cache, options = options)(0.9)
#print(sorted(zip(*matches)[1]))
print("length of log: %i" % len(log))
print("length of matches: %i" % len(matches))
# Out:
#          565447 function calls (565446 primitive calls) in 9.354 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.002    0.001    9.180    9.180 <string>:1(<module>)
#         4    0.000    0.000    0.055    0.014 Image.py:1395(resize)
#         4    0.000    0.000    0.055    0.014 Image.py:1637(thumbnail)
#         4    0.000    0.000    0.022    0.006 Image.py:1862(new)
#         4    0.000    0.000    0.046    0.012 Image.py:1890(frombytes)
#         4    0.000    0.000    0.047    0.012 Image.py:1938(frombuffer)
#         4    0.000    0.000    0.047    0.012 Image.py:1999(fromarray)
#         2    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         4    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         2    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#        12    0.000    0.000    0.000    0.000 Image.py:468(__init__)
# ...

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 140)#, filename= "frame")

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 300, alt=True)#, filename= "frame")

# %%
t = numpy.empty(0)
p = numpy.array([14, 54])
ps = numpy.append(t,p)
ps = numpy.append(ps,p)
#ps = numpy.append(ps, p.T, axis=0)
ps.reshape((ps.size / 2, 2))
# Out:
# array([[ 14.,  54.],
#        [ 14.,  54.]])

# %%
len(numpy.array([[1,2],[3,4]]))
# Out:
# 2
