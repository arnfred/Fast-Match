# %%
# %load_ext autoreload
# %autoreload 2

# %%
import figures
import itertools
import fastmatch
import matchutil
from imaging import open_img
from cache import Metric_Cache, Grid_Cache
import cProfile

# %%
target_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG"
query_path = "../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG"
query_cache = Metric_Cache(query_path)
target_img = open_img(target_path)
query_img = open_img(query_path)

# %%
log = []
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : 1.0,
           "grid_size" : (90, 90),
           "grid_margin" : 25,
           "radius" : 50,
           "thumb_size" : (250,250),
           "log" : log}
#profile.run('list(match_fun(0.9, 0.9))')
cProfile.run('list(fastmatch.match(query_cache, target_img, options = options)(0.8))')
#matches = fastmatch.match(query_cache, target_img, options = options)(0.7)
#print(sorted(zip(*matches)[1]))
print("length of log: %i" % len(log))
#print("length of matches: %i" % len(matches))
# Out:
#          6476 function calls in 0.360 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-0ccdf19897ac>:4(<lambda>)
#         1    0.000    0.000    0.360    0.360 <string>:1(<module>)
#         2    0.000    0.000    0.022    0.011 Image.py:1395(resize)
#         2    0.000    0.000    0.022    0.011 Image.py:1637(thumbnail)
#         2    0.000    0.000    0.010    0.005 Image.py:1862(new)
#         2    0.000    0.000    0.022    0.011 Image.py:1890(frombytes)
#         2    0.000    0.000    0.022    0.011 Image.py:1938(frombuffer)
#         2    0.000    0.000    0.022    0.011 Image.py:1999(fromarray)
#         1    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         2    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         1    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
# ...

# %%
#for i in range(87) :
figures.visualize_log(log, query_img, target_img, stop_at = 207)#, filename= "frame")
