# %%
# %load_ext autoreload
# %autoreload 2

# %%
import turntable
from cache import Metric_Cache, Grid_Cache
import fastmatch
import imaging
import cv2
import figures
import profile

# %%
options = {"evaluate_verbose" : True, "distance_threshold" : 5, "thumb_strategy" : lambda n : n}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Mean: %.4f" % numpy.mean(accu))
print("Median: %.4f" % numpy.median(accu))
print("Max: %.4f" % numpy.max(accu))
print("Min: %.4f" % numpy.min(accu))

profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options)')
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Mean: 0.1148
# Median: 0.0944
# Max: 0.2143
# Min: 0.0000
#  352196 function calls (343299 primitive calls) in 5.607 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1643    0.011    0.000    0.011    0.000 :0(BFMatcher)
#       139    0.001    0.000    0.001    0.000 :0(SIFT)
#        15    0.000    0.000    0.000    0.000 :0(StringIO)
#        28    0.000    0.000    0.000    0.000 :0(__import__)
#        44    0.000    0.000    0.000    0.000 :0(__setstate__)
#        24    0.000    0.000    0.000    0.000 :0(_reconstruct)
#        39    0.000    0.000    0.001    0.000 :0(all)
#      4568    0.014    0.000    0.014    0.000 :0(append)
#         1    0.000    0.000    0.000    0.000 :0(arange)
#      1643    0.013    0.000    0.013    0.000 :0(argsort)
#     43408    0.278    0.000    0.279    0.000 :0(array)
#     13976    0.056    0.000    0.056    0.000 :0(block)
#        39    0.000    0.000    0.000    0.000 :0(chr)
#        89    0.001    0.000    0.001    0.000 :0(close)
#        83    0.001    0.000    0.001    0.000 :0(computeCorrespondEpilines)
#        12    0.000    0.000    0.000    0.000 :0(copy)
#       180    0.003    0.000    0.003    0.000 :0(crc32)
#        74    0.037    0.000    0.037    0.000 :0(decode)
#       139    1.052    0.008    1.052    0.008 :0(detectAndCompute)
#     66761    0.661    0.000    0.661    0.000 :0(dot)
#        39    0.000    0.000    0.000    0.000 :0(empty)
#        18    0.001    0.000    0.001    0.000 :0(encode)
#       107    0.000    0.000    0.000    0.000 :0(endswith)
#       210    0.005    0.000    0.006    0.000 :0(eval)
#        39    0.001    0.000    0.001    0.000 :0(expr)
#         6    0.028    0.005    0.028    0.005 :0(fill)
#        39    0.000    0.000    0.000    0.000 :0(find)
#        43    0.000    0.000    0.000    0.000 :0(frombuffer)
#     11956    0.389    0.000    1.474    0.000 :0(get)
#      6134    0.028    0.000    0.028    0.000 :0(get_neighbor)
#      3032    0.009    0.000    0.009    0.000 :0(getattr)
#      3393    0.011    0.000    0.011    0.000 :0(hasattr)
#         3    0.105    0.035    0.105    0.035 :0(imread)
#        39    0.000    0.000    0.000    0.000 :0(insert)
#      2366    0.009    0.000    0.009    0.000 :0(isinstance)
#        39    0.000    0.000    0.000    0.000 :0(items)
#        10    0.000    0.000    0.000    0.000 :0(iteritems)
#         3    0.000    0.000    0.000    0.000 :0(join)
#        40    0.000    0.000    0.000    0.000 :0(keys)
#      1643    0.103    0.000    0.103    0.000 :0(knnMatch)
#     57425    0.199    0.000    0.199    0.000 :0(len)
#        10    0.002    0.000    0.002    0.000 :0(listdir)
# 3110/3080    0.015    0.000    0.849    0.000 :0(map)
#      2370    0.008    0.000    0.008    0.000 :0(match)
#       111    0.000    0.000    0.000    0.000 :0(max)
#       184    0.001    0.000    0.001    0.000 :0(min)
#         4    0.000    0.000    0.000    0.000 :0(new)
#         8    0.000    0.000    0.000    0.000 :0(newObj)
#      1640    0.009    0.000    0.009    0.000 :0(offset)
#        11    0.000    0.000    0.000    0.000 :0(open)
#        15    0.000    0.000    0.000    0.000 :0(pixel_access)
#       124    0.000    0.000    0.000    0.000 :0(pop)
#        11    0.000    0.000    0.000    0.000 :0(proxy)
#      1426    0.005    0.000    0.005    0.000 :0(range)
#         6    0.000    0.000    0.000    0.000 :0(raw_decoder)
#         3    0.000    0.000    0.000    0.000 :0(raw_encoder)
#      1654    0.006    0.000    0.006    0.000 :0(read)
#       768    0.002    0.000    0.002    0.000 :0(readline)
#      1956    0.031    0.000    0.031    0.000 :0(reduce)
#        11    0.000    0.000    0.000    0.000 :0(replace)
#      1884    0.011    0.000    0.011    0.000 :0(reshape)
#         3    0.004    0.001    0.004    0.001 :0(resize)
#       133    0.001    0.000    0.001    0.000 :0(seek)
#         9    0.000    0.000    0.000    0.000 :0(setimage)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#        49    0.000    0.000    0.000    0.000 :0(sorted)
#        39    0.000    0.000    0.000    0.000 :0(st2tuple)
#       144    0.000    0.000    0.000    0.000 :0(startswith)
#         4    0.000    0.000    0.000    0.000 :0(stat)
#         3    0.141    0.047    0.141    0.047 :0(stretch)
#      1821    0.012    0.000    0.053    0.000 :0(sum)
#        11    0.000    0.000    0.000    0.000 :0(tell)
#       178    0.001    0.000    0.001    0.000 :0(unpack)
#         1    0.000    0.000    0.000    0.000 :0(values)
#      1805    0.016    0.000    0.016    0.000 :0(zip)
#     211/1    0.004    0.000    5.607    5.607 <string>:1(<module>)
#         6    0.000    0.000    0.146    0.024 Image.py:1395(resize)
#         6    0.000    0.000    0.146    0.024 Image.py:1637(thumbnail)
#         6    0.000    0.000    0.028    0.005 Image.py:1862(new)
#         6    0.000    0.000    0.064    0.011 Image.py:1890(frombytes)
#         6    0.000    0.000    0.064    0.011 Image.py:1938(frombuffer)
#         6    0.000    0.000    0.064    0.011 Image.py:1999(fromarray)
#         3    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         6    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         3    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#        18    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#        12    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         6    0.000    0.000    0.001    0.000 Image.py:528(__getattr__)
#         3    0.000    0.000    0.001    0.000 Image.py:539(tobytes)
#         6    0.000    0.000    0.036    0.006 Image.py:603(frombytes)
#        15    0.000    0.000    0.000    0.000 Image.py:637(load)
#         6    0.000    0.000    0.000    0.000 Image.py:895(draft)
#        81    0.001    0.000    0.003    0.000 _methods.py:19(_amin)
#      1801    0.013    0.000    0.041    0.000 _methods.py:23(_sum)
#        39    0.000    0.000    0.001    0.000 _methods.py:35(_all)
#         6    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#        39    0.000    0.000    0.000    0.000 ast.py:1310(__init__)
#       210    0.001    0.000    0.001    0.000 ast.py:361(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:404(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:41(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:47(getChildNodes)
#        39    0.000    0.000    0.000    0.000 ast.py:984(__init__)
#      1801    0.011    0.000    0.017    0.000 base.py:702(isspmatrix)
#      1801    0.464    0.000    2.433    0.001 fastmatch.py:113(match_position)
#         3    0.000    0.000    0.528    0.176 fastmatch.py:27(match)
#        60    0.001    0.000    0.001    0.000 fastmatch.py:37(get_matches)
#      1333    0.244    0.000    2.891    0.002 fastmatch.py:45(do_iter)
#      6134    0.064    0.000    0.117    0.000 fastmatch.py:72(get_neighbor)
#         3    0.002    0.001    0.528    0.176 fastmatch.py:78(match_thumbs)
#        10    0.007    0.001    0.016    0.002 fnmatch.py:45(filter)
#        39    0.000    0.000    0.006    0.000 format.py:179(read_magic)
#        39    0.002    0.000    0.187    0.005 format.py:291(read_array_header_1_0)
#        39    0.003    0.000    0.207    0.005 format.py:412(read_array)
#       160    0.003    0.000    0.021    0.000 format.py:589(_read_bytes)
#        39    0.000    0.000    0.002    0.000 fromnumeric.py:1842(all)
#        81    0.001    0.000    0.003    0.000 fromnumeric.py:2132(amin)
#      1643    0.011    0.000    0.024    0.000 fromnumeric.py:792(argsort)
#         1    0.000    0.000    0.000    0.000 function_base.py:8(linspace)
#         4    0.000    0.000    0.000    0.000 genericpath.py:26(isfile)
#         4    0.000    0.000    0.000    0.000 hashlib.py:113(__hash_new)
#         6    0.000    0.000    0.064    0.011 imaging.py:21(__init__)
#         3    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         6    0.000    0.000    0.064    0.011 imaging.py:43(from_array)
#         9    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         3    0.000    0.000    0.146    0.049 imaging.py:52(scale)
#         6    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         3    0.000    0.000    0.181    0.060 imaging.py:80(get_thumbnail)
#         3    0.000    0.000    0.031    0.010 imaging.py:84(get_size)
#         3    0.000    0.000    0.105    0.035 imaging.py:94(open_cv)
#         3    0.000    0.000    0.105    0.035 imaging.py:97(open_img)
#       139    0.002    0.000    1.054    0.008 matchutil.py:22(get_features)
#        11    0.000    0.000    0.000    0.000 npyio.py:119(__init__)
#        11    0.000    0.000    0.006    0.001 npyio.py:128(zipfile_factory)
#        11    0.000    0.000    0.007    0.001 npyio.py:189(__init__)
#        11    0.000    0.000    0.001    0.000 npyio.py:213(close)
#        11    0.000    0.000    0.001    0.000 npyio.py:226(__del__)
#        39    0.001    0.000    0.221    0.006 npyio.py:229(__getitem__)
#        11    0.000    0.000    0.008    0.001 npyio.py:284(load)
#      3602    0.023    0.000    0.048    0.000 numeric.py:392(asarray)
#      3641    0.023    0.000    0.038    0.000 numeric.py:462(asanyarray)
#         4    0.000    0.000    0.000    0.000 pickle.py:1027(load_dict)
#        28    0.000    0.000    0.001    0.000 pickle.py:1087(load_global)
#        28    0.000    0.000    0.001    0.000 pickle.py:1122(find_class)
#        44    0.000    0.000    0.001    0.000 pickle.py:1129(load_reduce)
#       112    0.001    0.000    0.002    0.000 pickle.py:1150(load_get)
#       300    0.002    0.000    0.003    0.000 pickle.py:1164(load_put)
#        16    0.000    0.000    0.000    0.000 pickle.py:1193(load_setitem)
#        44    0.001    0.000    0.001    0.000 pickle.py:1211(load_build)
#       160    0.001    0.000    0.001    0.000 pickle.py:1250(load_mark)
#         4    0.000    0.000    0.000    0.000 pickle.py:1254(load_stop)
#         4    0.000    0.000    0.033    0.008 pickle.py:1380(loads)
#         4    0.000    0.000    0.000    0.000 pickle.py:829(__init__)
#         4    0.000    0.000    0.000    0.000 pickle.py:83(__init__)
#         4    0.008    0.002    0.033    0.008 pickle.py:845(load)
#       160    0.001    0.000    0.002    0.000 pickle.py:870(marker)
#        28    0.000    0.000    0.000    0.000 pickle.py:899(load_none)
#       228    0.002    0.000    0.004    0.000 pickle.py:911(load_int)
#         4    0.000    0.000    0.000    0.000 pickle.py:953(load_float)
#        68    0.002    0.000    0.005    0.000 pickle.py:961(load_string)
#       156    0.001    0.000    0.003    0.000 pickle.py:993(load_tuple)
#        10    0.000    0.000    0.000    0.000 posixpath.py:51(normcase)
#         0    0.000             0.000          profile:0(profiler)
#         1    0.000    0.000    5.607    5.607 profile:0(turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options))
#        39    0.000    0.000    0.000    0.000 py3k.py:61(isfileobj)
#      1801    0.045    0.000    0.086    0.000 shape_base.py:60(atleast_2d)
#      1801    0.037    0.000    0.081    0.000 shape_base.py:8(atleast_1d)
#         4    0.000    0.000    0.000    0.000 stat.py:24(S_IFMT)
#         4    0.000    0.000    0.000    0.000 stat.py:49(S_ISREG)
#        39    0.018    0.000    0.036    0.001 transformer.py:104(__init__)
#   1709/39    0.023    0.000    0.124    0.003 transformer.py:1077(com_binary)
#        39    0.001    0.000    0.127    0.003 transformer.py:120(transform)
#        39    0.002    0.000    0.111    0.003 transformer.py:1211(com_dictorsetmaker)
#        39    0.001    0.000    0.128    0.003 transformer.py:130(parseexpr)
#        39    0.000    0.000    0.126    0.003 transformer.py:145(compile_node)
#        39    0.000    0.000    0.125    0.003 transformer.py:191(eval_input)
#        39    0.000    0.000    0.165    0.004 transformer.py:49(parse)
#     74/39    0.001    0.000    0.125    0.003 transformer.py:574(testlist)
#        35    0.000    0.000    0.023    0.001 transformer.py:584(testlist_comp)
#    327/39    0.004    0.000    0.123    0.003 transformer.py:592(test)
#    327/39    0.003    0.000    0.122    0.003 transformer.py:606(or_test)
#    327/39    0.002    0.000    0.121    0.003 transformer.py:613(and_test)
#    327/39    0.003    0.000    0.120    0.003 transformer.py:617(not_test)
#    327/39    0.003    0.000    0.119    0.003 transformer.py:624(comparison)
#    327/39    0.002    0.000    0.119    0.003 transformer.py:657(expr)
#    327/39    0.002    0.000    0.118    0.003 transformer.py:661(xor_expr)
#    327/39    0.002    0.000    0.117    0.003 transformer.py:665(and_expr)
#    327/39    0.004    0.000    0.116    0.003 transformer.py:669(shift_expr)
#    327/39    0.004    0.000    0.115    0.003 transformer.py:682(arith_expr)
#    327/39    0.004    0.000    0.114    0.003 transformer.py:694(term)
#    327/39    0.003    0.000    0.113    0.003 transformer.py:712(factor)
#     70/35    0.001    0.000    0.001    0.000 transformer.py:72(extractLineNo)
#    327/39    0.004    0.000    0.112    0.003 transformer.py:725(power)
#    327/39    0.002    0.000    0.111    0.003 transformer.py:738(atom)
#        39    0.000    0.000    0.024    0.001 transformer.py:741(atom_lpar)
#        39    0.000    0.000    0.111    0.003 transformer.py:751(atom_lbrace)
#        54    0.001    0.000    0.003    0.000 transformer.py:759(atom_number)
#       156    0.001    0.000    0.005    0.000 transformer.py:764(decode_literal)
#       156    0.002    0.000    0.007    0.000 transformer.py:775(atom_string)
#        39    0.000    0.000    0.000    0.000 transformer.py:781(atom_name)
#      2055    0.006    0.000    0.006    0.000 transformer.py:797(lookup_node)
#   2597/39    0.017    0.000    0.125    0.003 transformer.py:800(com_node)
#        10    0.000    0.000    0.018    0.002 turntable.py:106(get_turntable_path)
#         3    0.000    0.000    0.019    0.006 turntable.py:161(get_fundamental_matrix)
#         1    0.002    0.002    1.868    1.868 turntable.py:220(match_distances)
#       281    0.399    0.001    1.784    0.006 turntable.py:250(calc_match_distances)
#     66761    0.715    0.000    1.376    0.000 turntable.py:258(dist)
#        83    0.003    0.000    0.005    0.000 turntable.py:262(get_lines)
#        10    0.000    0.000    0.000    0.000 turntable.py:289(get_image_set)
#         1    0.000    0.000    5.604    5.604 turntable.py:32(evaluate)
#        60    0.000    0.000    0.000    0.000 turntable.py:45(<lambda>)
#         3    0.000    0.000    0.016    0.005 turntable.py:48(get_path)
#         3    0.001    0.000    0.834    0.278 turntable.py:58(get_match_fun)
#        80    0.001    0.000    0.002    0.000 turntable.py:67(<genexpr>)
#        20    0.006    0.000    2.900    0.145 turntable.py:67(<lambda>)
#         1    0.000    0.000    0.000    0.000 turntable.py:71(<dictcomp>)
#        20    0.001    0.000    0.001    0.000 turntable.py:75(<lambda>)
#        39    0.000    0.000    0.000    0.000 utils.py:1008(visitName)
#        39    0.001    0.000    0.175    0.004 utils.py:1072(safe_eval)
#    366/39    0.004    0.000    0.008    0.000 utils.py:977(visit)
#        39    0.000    0.000    0.007    0.000 utils.py:986(visitExpression)
#       210    0.001    0.000    0.001    0.000 utils.py:990(visitConst)
#        39    0.001    0.000    0.006    0.000 utils.py:993(visitDict)
#        39    0.000    0.000    0.001    0.000 utils.py:996(visitTuple)
#      1801    0.023    0.000    0.077    0.000 validation.py:23(_assert_all_finite)
#      1801    0.036    0.000    0.241    0.000 validation.py:86(array2d)
#        39    0.000    0.000    0.000    0.000 warnings.py:318(__init__)
#        39    0.000    0.000    0.000    0.000 warnings.py:339(__enter__)
#        39    0.000    0.000    0.000    0.000 warnings.py:355(__exit__)
#        39    0.000    0.000    0.001    0.000 warnings.py:74(simplefilter)
#        11    0.000    0.000    0.000    0.000 zipfile.py:1247(__del__)
#        22    0.000    0.000    0.000    0.000 zipfile.py:1251(close)
#        11    0.000    0.000    0.001    0.000 zipfile.py:158(_EndRecData64)
#        11    0.001    0.000    0.002    0.000 zipfile.py:201(_EndRecData)
#        39    0.000    0.000    0.001    0.000 zipfile.py:287(__init__)
#        39    0.000    0.000    0.000    0.000 zipfile.py:377(_decodeFilename)
#        39    0.000    0.000    0.000    0.000 zipfile.py:383(_decodeExtra)
#        78    0.001    0.000    0.002    0.000 zipfile.py:515(__init__)
#       199    0.004    0.000    0.020    0.000 zipfile.py:621(read)
#       102    0.001    0.000    0.004    0.000 zipfile.py:639(_update_crc)
#       199    0.006    0.000    0.014    0.000 zipfile.py:649(read1)
#        78    0.001    0.000    0.001    0.000 zipfile.py:701(close)
#        11    0.000    0.000    0.006    0.001 zipfile.py:726(__init__)
#        11    0.002    0.000    0.006    0.001 zipfile.py:803(_RealGetContents)
#        11    0.000    0.000    0.000    0.000 zipfile.py:872(namelist)
#        78    0.000    0.000    0.001    0.000 zipfile.py:904(getinfo)
#        78    0.003    0.000    0.008    0.000 zipfile.py:937(open)

# %%
options = {"evaluate_verbose" : True, "distance_threshold" : 5, "thumb_strategy" : lambda n : n/2.0 + 0.5}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Mean: %.4f" % numpy.mean(accu))
print("Median: %.4f" % numpy.median(accu))
print("Max: %.4f" % numpy.max(accu))
print("Min: %.4f" % numpy.min(accu))

#profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options)')
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# (2,)
# [autoreload of fastmatch failed: Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "fastmatch.py", line 126
#     target_kp, target_ds = target.get(numpy.array(pos_target, dtype=numpy.double)))
#                                                                                   ^
# SyntaxError: invalid syntax
# ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-383b985ef102> in <module>()
#       1 options = {"evaluate_verbose" : True, "distance_threshold" : 5, "thumb_strategy" : lambda n : n/2.0 + 0.5}
# ----> 2 results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options = options)
#       3 accu = numpy.array(results["accuracy"], dtype=numpy.float)
#       4 print("Mean: %.4f" % numpy.mean(accu))
#       5 print("Median: %.4f" % numpy.median(accu))
#
# /home/arnfred/Experiments/fastmatch/turntable.pyc in evaluate(match_fun, angles, object_type, thresholds, ground_truth_data, options)
#      66     match_functions = map(get_match_fun, range(3))
#      67     apply_threshold = lambda tau : list(chain(*(f(tau, thumb_strategy(tau)) for f in match_functions)))
# ---> 68     matches = [apply_threshold(tau) for tau in thresholds]
#      69
#      70     # Get distances for the highest threshold (they include all other)
#
# /home/arnfred/Experiments/fastmatch/turntable.pyc in <lambda>(tau)
#      65     # Get matches
#      66     match_functions = map(get_match_fun, range(3))
# ---> 67     apply_threshold = lambda tau : list(chain(*(f(tau, thumb_strategy(tau)) for f in match_functions)))
#      68     matches = [apply_threshold(tau) for tau in thresholds]
#      69
#
# /home/arnfred/Experiments/fastmatch/fastmatch.pyc in do_iter(positions, cache, target_grid, tau, log)
#      52         if not has_matched.get((col, row, query_col, query_row), False) :
#      53             has_matched[(col, row, query_col, query_row)] = True
# ---> 54             result_pos, ratios = match_position((query_pos, target_pos), cache, target_grid)
#      55             # For each match we don't discard, we might want to examine the neighbor field
#      56             neighbor_pos = [(p[0], get_neighbor(target_pos, p[1], target_grid))
#
# /home/arnfred/Experiments/fastmatch/fastmatch.pyc in match_position(pos, cache, target)
#     124
#     125     print(numpy.array(pos_target, dtype=numpy.double).shape)
# --> 126     target_kp, target_ds = target.get(numpy.array(pos_target, dtype=numpy.double)))
#     127     if target_ds == None :
#     128         return numpy.array([]), numpy.array([])
#
# /home/arnfred/Experiments/fastmatch/cache.so in cache.Grid_Cache.get (cache.c:2270)()
#
# /home/arnfred/Experiments/fastmatch/cache.so in cache.Grid_Cache.get (cache.c:2212)()
#
# /home/arnfred/Experiments/fastmatch/cache.so in cache.Grid_Cache.get_cell (cache.c:2378)()
#
# /home/arnfred/Experiments/fastmatch/cache.so in cache.Grid_Cache.cache (cache.c:3604)()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 3)

# %%
options = {"evaluate_verbose" : True, "distance_threshold" : 5, "thumb_strategy" : lambda n : n+0.2}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Mean: %.4f" % numpy.mean(accu))
print("Median: %.4f" % numpy.median(accu))
print("Max: %.4f" % numpy.max(accu))
print("Min: %.4f" % numpy.min(accu))

#profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1, 20), options)')
# Out:
# 0.7
# tau: (0.50, 0.70)
# tau: (0.53, 0.73)
# tau: (0.55, 0.75)
# tau: (0.58, 0.78)
# tau: (0.61, 0.81)
# tau: (0.63, 0.83)
# tau: (0.66, 0.86)
# tau: (0.68, 0.88)
# tau: (0.71, 0.91)
# tau: (0.74, 0.94)
# tau: (0.76, 0.96)
# tau: (0.79, 0.99)
# tau: (0.82, 1.02)
# tau: (0.84, 1.04)
# tau: (0.87, 1.07)
# tau: (0.89, 1.09)
# tau: (0.92, 1.12)
# tau: (0.95, 1.15)
# tau: (0.97, 1.17)
# tau: (1.00, 1.20)
# Mean: 0.1037
# Median: 0.1013
# Max: 0.1667
# Min: 0.0000

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : n/2+0.5,
           "grid_size" : (200, 200)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   0', '   1', '   3', '   4', '   6', '  11', '  12', '  17', '  24', '  32', '  37', '  44', '  51', '  56', '  60']
# Total:	  ['   4', '   9', '  13', '  23', '  46', '  80', ' 108', ' 163', ' 246', ' 382', ' 524', ' 751', '1002', '1333', '1553']
# Accuracy: ['0.00', '0.11', '0.23', '0.17', '0.13', '0.14', '0.11', '0.10', '0.10', '0.08', '0.07', '0.06', '0.05', '0.04', '0.04']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : n/2+0.5,
           "grid_size" : (150, 150)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   0', '   2', '   3', '   3', '   6', '  12', '  13', '  21', '  26', '  35', '  46', '  52', '  61', '  70', '  79']
# Total:	  ['  10', '  17', '  23', '  28', '  39', '  75', '  98', ' 161', ' 231', ' 384', ' 600', ' 840', '1089', '1481', '1926']
# Accuracy: ['0.00', '0.12', '0.13', '0.11', '0.15', '0.16', '0.13', '0.13', '0.11', '0.09', '0.08', '0.06', '0.06', '0.05', '0.04']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : n/2+0.5,
           "grid_size" : (100, 100)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   0', '   1', '   3', '   3', '   5', '   6', '  10', '  17', '  25', '  38', '  49', '  55', '  65', '  78', '  86']
# Total:	  ['   3', '   9', '  15', '  23', '  39', '  61', '  88', ' 144', ' 204', ' 352', ' 521', ' 742', '1048', '1566', '2020']
# Accuracy: ['0.00', '0.11', '0.20', '0.13', '0.13', '0.10', '0.11', '0.12', '0.12', '0.11', '0.09', '0.07', '0.06', '0.05', '0.04']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : n/2+0.5,
           "grid_size" : (75, 75),
            "grid_margin" : 45}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   1', '   3', '   5', '   7', '   8', '  19', '  28', '  41', '  59', '  72', '  86', ' 101', ' 117', ' 136']
# Total:	  ['  10', '  16', '  23', '  35', '  47', '  63', ' 111', ' 172', ' 242', ' 432', ' 679', '1022', '1447', '2007', '2735']
# Accuracy: ['0.10', '0.06', '0.13', '0.14', '0.15', '0.13', '0.17', '0.16', '0.17', '0.14', '0.11', '0.08', '0.07', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : n+0.2,
           "grid_size" : (75, 75),
           "grid_margin" : 40}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   2', '   2', '   2', '   3', '   6', '  19', '  25', '  32', '  49', '  65', '  74', '  86', ' 107', ' 118']
# Total:	  ['   6', '   8', '  11', '  23', '  31', '  64', ' 103', ' 149', ' 224', ' 413', ' 676', ' 995', '1384', '1925', '2575']
# Accuracy: ['0.17', '0.25', '0.18', '0.09', '0.10', '0.09', '0.18', '0.17', '0.14', '0.12', '0.10', '0.07', '0.06', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (400, 400)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   2', '   2', '   2', '   3', '   6', '  19', '  25', '  32', '  47', '  63', '  73', '  86', ' 107', ' 118']
# Total:	  ['   4', '   6', '  11', '  16', '  31', '  64', ' 103', ' 147', ' 212', ' 389', ' 641', ' 941', '1294', '1850', '2573']
# Accuracy: ['0.25', '0.33', '0.18', '0.12', '0.10', '0.09', '0.18', '0.17', '0.15', '0.12', '0.10', '0.08', '0.07', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (300, 300)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.5, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   4', '  12', '  19', '  39', '  62', '  76', ' 105', ' 122', ' 148', ' 160', ' 184', ' 207']
# Total:	  ['   8', '  17', '  25', '  41', '  77', ' 134', ' 263', ' 589', '1027', '1615', '2663', '3774', '4886', '6225', '7189']
# Accuracy: ['0.12', '0.18', '0.12', '0.10', '0.16', '0.14', '0.15', '0.11', '0.07', '0.07', '0.05', '0.04', '0.03', '0.03', '0.03']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (300, 300)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   2', '   2', '   3', '   4', '   8', '  15', '  20', '  27', '  35', '  42', '  47', '  54', '  58', '  61']
# Total:	  ['   4', '   6', '   8', '  25', '  42', '  78', ' 102', ' 137', ' 180', ' 245', ' 334', ' 432', ' 523', ' 641', ' 771']
# Accuracy: ['0.25', '0.33', '0.25', '0.12', '0.10', '0.10', '0.15', '0.15', '0.15', '0.14', '0.13', '0.11', '0.10', '0.09', '0.08']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (200, 200)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   0', '   2', '   2', '   2', '   3', '   3', '  16', '  21', '  28', '  47', '  63', '  72', '  87', ' 107', ' 120']
# Total:	  ['   1', '   8', '  11', '  19', '  29', '  56', '  94', ' 138', ' 192', ' 398', ' 648', ' 947', '1325', '1742', '2582']
# Accuracy: ['0.00', '0.25', '0.18', '0.11', '0.10', '0.05', '0.17', '0.15', '0.15', '0.12', '0.10', '0.08', '0.07', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : 1,
           "grid_size" : (75, 75),
           "grid_margin" : 20}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   0', '   0', '   1', '   1', '   3', '   5', '   9', '  13', '  19', '  35', '  42', '  54', '  62', '  73', '  89']
# Total:	  ['   5', '   8', '  10', '  12', '  18', '  39', '  70', ' 104', ' 146', ' 259', ' 373', ' 650', ' 876', '1221', '1614']
# Accuracy: ['0.00', '0.00', '0.10', '0.08', '0.17', '0.13', '0.13', '0.12', '0.13', '0.14', '0.11', '0.08', '0.07', '0.06', '0.06']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (300, 300)}
profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options)')
# Out:
# It works!
# It works!
# It works!
# It works!
#  1210757 function calls (1201858 primitive calls) in 17.733 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      5823    0.039    0.000    0.039    0.000 :0(BFMatcher)
#       266    0.001    0.000    0.001    0.000 :0(SIFT)
#        15    0.000    0.000    0.000    0.000 :0(StringIO)
#        28    0.000    0.000    0.000    0.000 :0(__import__)
#        44    0.000    0.000    0.000    0.000 :0(__setstate__)
#        24    0.000    0.000    0.000    0.000 :0(_reconstruct)
#        39    0.000    0.000    0.001    0.000 :0(all)
#     12965    0.041    0.000    0.041    0.000 :0(append)
#         1    0.000    0.000    0.000    0.000 :0(arange)
#      5823    0.045    0.000    0.045    0.000 :0(argsort)
#    207079    1.340    0.000    1.341    0.000 :0(array)
#        39    0.000    0.000    0.000    0.000 :0(chr)
#        92    0.001    0.000    0.001    0.000 :0(close)
#       249    0.003    0.000    0.003    0.000 :0(computeCorrespondEpilines)
#        24    0.000    0.000    0.000    0.000 :0(copy)
#         3    0.000    0.000    0.000    0.000 :0(count)
#       180    0.003    0.000    0.003    0.000 :0(crc32)
#        82    0.036    0.000    0.036    0.000 :0(decode)
#       266    1.737    0.007    1.737    0.007 :0(detectAndCompute)
#         3    0.000    0.000    0.000    0.000 :0(digest)
#    209624    2.116    0.000    2.116    0.000 :0(dot)
#        39    0.000    0.000    0.000    0.000 :0(empty)
#        18    0.001    0.000    0.001    0.000 :0(encode)
#       107    0.000    0.000    0.000    0.000 :0(endswith)
#       210    0.005    0.000    0.005    0.000 :0(eval)
#        39    0.001    0.000    0.001    0.000 :0(expr)
#         6    0.000    0.000    0.000    0.000 :0(extend)
#         6    0.028    0.005    0.028    0.005 :0(fill)
#        39    0.000    0.000    0.000    0.000 :0(find)
#        43    0.000    0.000    0.000    0.000 :0(frombuffer)
#     51666    0.189    0.000    0.189    0.000 :0(get)
#         3    0.000    0.000    0.000    0.000 :0(get_ident)
#      3035    0.009    0.000    0.009    0.000 :0(getattr)
#        17    0.000    0.000    0.000    0.000 :0(getpid)
#         3    0.000    0.000    0.000    0.000 :0(getvalue)
#      9391    0.033    0.000    0.033    0.000 :0(hasattr)
#         3    0.000    0.000    0.000    0.000 :0(hexdigest)
#         3    0.104    0.035    0.104    0.035 :0(imread)
#        39    0.000    0.000    0.000    0.000 :0(insert)
#     18621    0.067    0.000    0.067    0.000 :0(isinstance)
#         3    0.000    0.000    0.000    0.000 :0(isoformat)
#      5995    0.023    0.000    0.023    0.000 :0(issubclass)
#        39    0.000    0.000    0.000    0.000 :0(items)
#        10    0.000    0.000    0.000    0.000 :0(iteritems)
#        15    0.000    0.000    0.000    0.000 :0(join)
#        40    0.000    0.000    0.000    0.000 :0(keys)
#      5823    0.514    0.000    0.514    0.000 :0(knnMatch)
#    231228    0.845    0.000    0.845    0.000 :0(len)
#        10    0.002    0.000    0.002    0.000 :0(listdir)
#         3    0.000    0.000    0.000    0.000 :0(locals)
# 21465/21433    0.108    0.000    0.952    0.000 :0(map)
#      2370    0.009    0.000    0.009    0.000 :0(match)
#       114    0.000    0.000    0.000    0.000 :0(max)
#       184    0.001    0.000    0.001    0.000 :0(min)
#         4    0.000    0.000    0.000    0.000 :0(new)
#         8    0.000    0.000    0.000    0.000 :0(newObj)
#         3    0.000    0.000    0.000    0.000 :0(now)
#        11    0.000    0.000    0.000    0.000 :0(open)
#        15    0.000    0.000    0.000    0.000 :0(pixel_access)
#       124    0.000    0.000    0.000    0.000 :0(pop)
#        11    0.000    0.000    0.000    0.000 :0(proxy)
#      7424    0.026    0.000    0.026    0.000 :0(range)
#         6    0.000    0.000    0.000    0.000 :0(raw_decoder)
#         3    0.000    0.000    0.000    0.000 :0(raw_encoder)
#      1654    0.007    0.000    0.007    0.000 :0(read)
#       768    0.002    0.000    0.002    0.000 :0(readline)
#     12311    0.186    0.000    0.186    0.000 :0(reduce)
#        11    0.000    0.000    0.000    0.000 :0(replace)
#      6244    0.036    0.000    0.036    0.000 :0(reshape)
#         3    0.004    0.001    0.004    0.001 :0(resize)
#       133    0.001    0.000    0.001    0.000 :0(seek)
#        21    0.000    0.000    0.000    0.000 :0(send)
#         9    0.000    0.000    0.000    0.000 :0(setimage)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#        49    0.000    0.000    0.000    0.000 :0(sorted)
#        39    0.001    0.000    0.001    0.000 :0(st2tuple)
#       144    0.000    0.000    0.000    0.000 :0(startswith)
#         4    0.000    0.000    0.000    0.000 :0(stat)
#         3    0.141    0.047    0.141    0.047 :0(stretch)
#      6015    0.039    0.000    0.165    0.000 :0(sum)
#        11    0.000    0.000    0.000    0.000 :0(tell)
#         8    0.000    0.000    0.000    0.000 :0(time)
#       178    0.001    0.000    0.001    0.000 :0(unpack)
#        15    0.000    0.000    0.000    0.000 :0(update)
#         3    0.000    0.000    0.000    0.000 :0(upper)
#         8    0.000    0.000    0.000    0.000 :0(utf_8_decode)
#         1    0.000    0.000    0.000    0.000 :0(values)
#         8    0.000    0.000    0.000    0.000 :0(write)
#      5999    0.088    0.000    0.088    0.000 :0(zip)
#         3    0.000    0.000    0.000    0.000 :0(zmq_poll)
#     211/1    0.007    0.000   17.733   17.733 <string>:1(<module>)
#         6    0.000    0.000    0.145    0.024 Image.py:1395(resize)
#         6    0.000    0.000    0.146    0.024 Image.py:1637(thumbnail)
#         6    0.000    0.000    0.028    0.005 Image.py:1862(new)
#         6    0.000    0.000    0.064    0.011 Image.py:1890(frombytes)
#         6    0.000    0.000    0.064    0.011 Image.py:1938(frombuffer)
#         6    0.000    0.000    0.064    0.011 Image.py:1999(fromarray)
#         3    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         6    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         3    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#        18    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#        12    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         6    0.000    0.000    0.001    0.000 Image.py:528(__getattr__)
#         3    0.000    0.000    0.001    0.000 Image.py:539(tobytes)
#         6    0.000    0.000    0.035    0.006 Image.py:603(frombytes)
#        15    0.000    0.000    0.000    0.000 Image.py:637(load)
#         6    0.000    0.000    0.000    0.000 Image.py:895(draft)
#        12    0.000    0.000    0.001    0.000 __init__.py:193(dumps)
#         3    0.000    0.000    0.000    0.000 __init__.py:52(create_string_buffer)
#       247    0.002    0.000    0.007    0.000 _methods.py:19(_amin)
#      5995    0.044    0.000    0.126    0.000 _methods.py:23(_sum)
#        39    0.000    0.000    0.001    0.000 _methods.py:35(_all)
#      5995    0.075    0.000    0.115    0.000 _methods.py:39(_count_reduce_items)
#      5995    0.207    0.000    0.581    0.000 _methods.py:49(_mean)
#         6    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#        39    0.000    0.000    0.000    0.000 ast.py:1310(__init__)
#       210    0.001    0.000    0.001    0.000 ast.py:361(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:404(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:41(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:47(getChildNodes)
#        39    0.000    0.000    0.000    0.000 ast.py:984(__init__)
#         3    0.000    0.000    0.000    0.000 attrsettr.py:47(__getattr__)
#      5995    0.035    0.000    0.055    0.000 base.py:702(isspmatrix)
#        12    0.000    0.000    0.000    0.000 encoder.py:101(__init__)
#        12    0.000    0.000    0.001    0.000 encoder.py:186(encode)
#        12    0.000    0.000    0.000    0.000 encoder.py:212(iterencode)
#      5995    3.335    0.001    9.057    0.002 fastmatch.py:108(match_position)
#         3    0.000    0.000    0.528    0.176 fastmatch.py:27(match)
#        60    0.002    0.000    0.002    0.000 fastmatch.py:37(get_matches)
#      7786    1.136    0.000   11.045    0.001 fastmatch.py:45(do_iter)
#     42838    0.470    0.000    0.470    0.000 fastmatch.py:56(<lambda>)
#         3    0.002    0.001    0.528    0.176 fastmatch.py:73(match_thumbs)
#        10    0.008    0.001    0.017    0.002 fnmatch.py:45(filter)
#        39    0.000    0.000    0.007    0.000 format.py:179(read_magic)
#        39    0.003    0.000    0.195    0.005 format.py:291(read_array_header_1_0)
#        39    0.003    0.000    0.215    0.006 format.py:412(read_array)
#       160    0.003    0.000    0.021    0.000 format.py:589(_read_bytes)
#        39    0.000    0.000    0.003    0.000 fromnumeric.py:1842(all)
#       247    0.003    0.000    0.010    0.000 fromnumeric.py:2132(amin)
#      5995    0.077    0.000    0.657    0.000 fromnumeric.py:2632(mean)
#      5823    0.040    0.000    0.085    0.000 fromnumeric.py:792(argsort)
#         1    0.000    0.000    0.000    0.000 function_base.py:8(linspace)
#         4    0.000    0.000    0.000    0.000 genericpath.py:26(isfile)
#         4    0.000    0.000    0.000    0.000 hashlib.py:113(__hash_new)
#         3    0.000    0.000    0.000    0.000 hmac.py:116(hexdigest)
#         3    0.000    0.000    0.000    0.000 hmac.py:27(__init__)
#        12    0.000    0.000    0.000    0.000 hmac.py:80(update)
#         3    0.000    0.000    0.000    0.000 hmac.py:85(copy)
#         3    0.000    0.000    0.000    0.000 hmac.py:97(_current)
#         6    0.000    0.000    0.065    0.011 imaging.py:21(__init__)
#         3    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         6    0.000    0.000    0.064    0.011 imaging.py:43(from_array)
#         9    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         3    0.000    0.000    0.146    0.049 imaging.py:52(scale)
#         6    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         3    0.000    0.000    0.181    0.060 imaging.py:80(get_thumbnail)
#         3    0.000    0.000    0.031    0.010 imaging.py:84(get_size)
#         3    0.000    0.000    0.104    0.035 imaging.py:94(open_cv)
#         3    0.000    0.000    0.104    0.035 imaging.py:97(open_img)
#         3    0.000    0.000    0.000    0.000 iostream.py:116(_flush_from_subprocesses)
#         3    0.000    0.000    0.004    0.001 iostream.py:133(flush)
#         8    0.000    0.000    0.005    0.001 iostream.py:189(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:220(_flush_buffer)
#         3    0.000    0.000    0.000    0.000 iostream.py:229(_new_buffer)
#        14    0.000    0.000    0.000    0.000 iostream.py:90(_is_master_process)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_is_master_thread)
#        11    0.000    0.000    0.000    0.000 iostream.py:99(_check_mp_mode)
#        12    0.000    0.000    0.001    0.000 jsonapi.py:46(dumps)
#         3    0.000    0.000    0.000    0.000 jsonutil.py:114(date_default)
#       266    0.003    0.000    1.742    0.007 matchutil.py:22(get_features)
#        11    0.000    0.000    0.000    0.000 npyio.py:119(__init__)
#        11    0.000    0.000    0.006    0.001 npyio.py:128(zipfile_factory)
#        11    0.000    0.000    0.007    0.001 npyio.py:189(__init__)
#        11    0.000    0.000    0.001    0.000 npyio.py:213(close)
#        11    0.000    0.000    0.001    0.000 npyio.py:226(__del__)
#        39    0.001    0.000    0.230    0.006 npyio.py:229(__getitem__)
#        11    0.001    0.000    0.008    0.001 npyio.py:284(load)
#     11990    0.081    0.000    0.160    0.000 numeric.py:392(asarray)
#     18024    0.118    0.000    0.218    0.000 numeric.py:462(asanyarray)
#         4    0.000    0.000    0.000    0.000 pickle.py:1027(load_dict)
#        28    0.000    0.000    0.001    0.000 pickle.py:1087(load_global)
#        28    0.000    0.000    0.001    0.000 pickle.py:1122(find_class)
#        44    0.000    0.000    0.001    0.000 pickle.py:1129(load_reduce)
#       112    0.001    0.000    0.002    0.000 pickle.py:1150(load_get)
#       300    0.002    0.000    0.003    0.000 pickle.py:1164(load_put)
#        16    0.000    0.000    0.000    0.000 pickle.py:1193(load_setitem)
#        44    0.001    0.000    0.001    0.000 pickle.py:1211(load_build)
#       160    0.001    0.000    0.001    0.000 pickle.py:1250(load_mark)
#         4    0.000    0.000    0.000    0.000 pickle.py:1254(load_stop)
#         4    0.000    0.000    0.034    0.008 pickle.py:1380(loads)
#         4    0.000    0.000    0.000    0.000 pickle.py:829(__init__)
#         4    0.000    0.000    0.000    0.000 pickle.py:83(__init__)
#         4    0.008    0.002    0.034    0.008 pickle.py:845(load)
#       160    0.001    0.000    0.002    0.000 pickle.py:870(marker)
#        28    0.000    0.000    0.000    0.000 pickle.py:899(load_none)
#       228    0.002    0.000    0.004    0.000 pickle.py:911(load_int)
#         4    0.000    0.000    0.000    0.000 pickle.py:953(load_float)
#        68    0.002    0.000    0.005    0.000 pickle.py:961(load_string)
#       156    0.001    0.000    0.003    0.000 pickle.py:993(load_tuple)
#         3    0.000    0.000    0.000    0.000 poll.py:86(poll)
#        10    0.000    0.000    0.000    0.000 posixpath.py:51(normcase)
#         0    0.000             0.000          profile:0(profiler)
#         1    0.000    0.000   17.733   17.733 profile:0(turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options))
#         3    0.000    0.000    0.000    0.000 py3compat.py:13(no_code)
#        39    0.000    0.000    0.000    0.000 py3k.py:61(isfileobj)
#         3    0.000    0.000    0.000    0.000 session.py:192(msg_header)
#         3    0.000    0.000    0.000    0.000 session.py:196(extract_header)
#         3    0.000    0.000    0.001    0.000 session.py:426(msg_id)
#         3    0.000    0.000    0.001    0.000 session.py:478(msg_header)
#         3    0.000    0.000    0.001    0.000 session.py:481(msg)
#         3    0.000    0.000    0.000    0.000 session.py:500(sign)
#         3    0.000    0.000    0.002    0.001 session.py:515(serialize)
#         3    0.000    0.000    0.003    0.001 session.py:574(send)
#        12    0.000    0.000    0.001    0.000 session.py:83(<lambda>)
#      5995    0.151    0.000    0.289    0.000 shape_base.py:60(atleast_2d)
#      5995    0.125    0.000    0.275    0.000 shape_base.py:8(atleast_1d)
#         3    0.000    0.000    0.000    0.000 socket.py:239(send_multipart)
#         4    0.000    0.000    0.000    0.000 stat.py:24(S_IFMT)
#         4    0.000    0.000    0.000    0.000 stat.py:49(S_ISREG)
#         3    0.000    0.000    0.000    0.000 threading.py:1152(currentThread)
#         3    0.000    0.000    0.000    0.000 threading.py:983(ident)
#        36    0.000    0.000    0.000    0.000 traitlets.py:337(__get__)
#        39    0.018    0.000    0.037    0.001 transformer.py:104(__init__)
#   1709/39    0.024    0.000    0.129    0.003 transformer.py:1077(com_binary)
#        39    0.001    0.000    0.132    0.003 transformer.py:120(transform)
#        39    0.002    0.000    0.115    0.003 transformer.py:1211(com_dictorsetmaker)
#        39    0.001    0.000    0.133    0.003 transformer.py:130(parseexpr)
#        39    0.000    0.000    0.130    0.003 transformer.py:145(compile_node)
#        39    0.000    0.000    0.130    0.003 transformer.py:191(eval_input)
#        39    0.000    0.000    0.171    0.004 transformer.py:49(parse)
#     74/39    0.001    0.000    0.129    0.003 transformer.py:574(testlist)
#        35    0.000    0.000    0.024    0.001 transformer.py:584(testlist_comp)
#    327/39    0.004    0.000    0.128    0.003 transformer.py:592(test)
#    327/39    0.003    0.000    0.127    0.003 transformer.py:606(or_test)
#    327/39    0.002    0.000    0.126    0.003 transformer.py:613(and_test)
#    327/39    0.003    0.000    0.125    0.003 transformer.py:617(not_test)
#    327/39    0.004    0.000    0.124    0.003 transformer.py:624(comparison)
#    327/39    0.002    0.000    0.123    0.003 transformer.py:657(expr)
#    327/39    0.002    0.000    0.122    0.003 transformer.py:661(xor_expr)
#    327/39    0.002    0.000    0.121    0.003 transformer.py:665(and_expr)
#    327/39    0.004    0.000    0.120    0.003 transformer.py:669(shift_expr)
#    327/39    0.004    0.000    0.119    0.003 transformer.py:682(arith_expr)
#    327/39    0.004    0.000    0.118    0.003 transformer.py:694(term)
#    327/39    0.004    0.000    0.117    0.003 transformer.py:712(factor)
#     70/35    0.001    0.000    0.001    0.000 transformer.py:72(extractLineNo)
#    327/39    0.004    0.000    0.116    0.003 transformer.py:725(power)
#    327/39    0.002    0.000    0.115    0.003 transformer.py:738(atom)
#        39    0.000    0.000    0.025    0.001 transformer.py:741(atom_lpar)
#        39    0.000    0.000    0.115    0.003 transformer.py:751(atom_lbrace)
#        54    0.001    0.000    0.002    0.000 transformer.py:759(atom_number)
#       156    0.001    0.000    0.005    0.000 transformer.py:764(decode_literal)
#       156    0.002    0.000    0.007    0.000 transformer.py:775(atom_string)
#        39    0.000    0.000    0.000    0.000 transformer.py:781(atom_name)
#      2055    0.006    0.000    0.006    0.000 transformer.py:797(lookup_node)
#   2597/39    0.017    0.000    0.129    0.003 transformer.py:800(com_node)
#        10    0.000    0.000    0.019    0.002 turntable.py:106(get_turntable_path)
#         3    0.000    0.000    0.020    0.007 turntable.py:161(get_fundamental_matrix)
#         1    0.012    0.012    5.796    5.796 turntable.py:220(match_distances)
#      2146    1.267    0.001    5.695    0.003 turntable.py:250(calc_match_distances)
#    209624    2.256    0.000    4.372    0.000 turntable.py:258(dist)
#       249    0.010    0.000    0.015    0.000 turntable.py:262(get_lines)
#        10    0.000    0.000    0.000    0.000 turntable.py:289(get_image_set)
#         1    0.001    0.001   17.727   17.727 turntable.py:32(evaluate)
#        60    0.000    0.000    0.000    0.000 turntable.py:45(<lambda>)
#         3    0.000    0.000    0.017    0.006 turntable.py:48(get_path)
#         3    0.001    0.000    0.844    0.281 turntable.py:58(get_match_fun)
#        80    0.001    0.000    0.003    0.000 turntable.py:67(<genexpr>)
#        20    0.032    0.002   11.080    0.554 turntable.py:67(<lambda>)
#         1    0.002    0.002    0.002    0.002 turntable.py:71(<dictcomp>)
#        20    0.003    0.000    0.003    0.000 turntable.py:75(<lambda>)
#         8    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#        39    0.000    0.000    0.000    0.000 utils.py:1008(visitName)
#        39    0.001    0.000    0.181    0.005 utils.py:1072(safe_eval)
#    366/39    0.004    0.000    0.008    0.000 utils.py:977(visit)
#        39    0.000    0.000    0.007    0.000 utils.py:986(visitExpression)
#       210    0.001    0.000    0.001    0.000 utils.py:990(visitConst)
#        39    0.001    0.000    0.006    0.000 utils.py:993(visitDict)
#        39    0.000    0.000    0.001    0.000 utils.py:996(visitTuple)
#         3    0.000    0.000    0.000    0.000 uuid.py:101(__init__)
#         3    0.000    0.000    0.000    0.000 uuid.py:197(__str__)
#         3    0.000    0.000    0.000    0.000 uuid.py:546(uuid4)
#      5995    0.076    0.000    0.241    0.000 validation.py:23(_assert_all_finite)
#      5995    0.119    0.000    0.787    0.000 validation.py:86(array2d)
#        39    0.000    0.000    0.000    0.000 warnings.py:318(__init__)
#        39    0.000    0.000    0.000    0.000 warnings.py:339(__enter__)
#        39    0.000    0.000    0.000    0.000 warnings.py:355(__exit__)
#        39    0.000    0.000    0.001    0.000 warnings.py:74(simplefilter)
#        11    0.000    0.000    0.000    0.000 zipfile.py:1247(__del__)
#        22    0.000    0.000    0.000    0.000 zipfile.py:1251(close)
#        11    0.000    0.000    0.001    0.000 zipfile.py:158(_EndRecData64)
#        11    0.001    0.000    0.002    0.000 zipfile.py:201(_EndRecData)
#        39    0.000    0.000    0.001    0.000 zipfile.py:287(__init__)
#        39    0.000    0.000    0.000    0.000 zipfile.py:377(_decodeFilename)
#        39    0.000    0.000    0.000    0.000 zipfile.py:383(_decodeExtra)
#        78    0.001    0.000    0.002    0.000 zipfile.py:515(__init__)
#       199    0.004    0.000    0.021    0.000 zipfile.py:621(read)
#       102    0.001    0.000    0.004    0.000 zipfile.py:639(_update_crc)
#       199    0.006    0.000    0.014    0.000 zipfile.py:649(read1)
#        78    0.001    0.000    0.001    0.000 zipfile.py:701(close)
#        11    0.000    0.000    0.006    0.001 zipfile.py:726(__init__)
#        11    0.002    0.000    0.006    0.001 zipfile.py:803(_RealGetContents)
#        11    0.000    0.000    0.000    0.000 zipfile.py:872(namelist)
#        78    0.001    0.000    0.001    0.000 zipfile.py:904(getinfo)
#        78    0.003    0.000    0.008    0.000 zipfile.py:937(open)

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
           "thumb_size" : (300, 300)}
profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options)')
# Out:
#          1311802 function calls (1302905 primitive calls) in 18.049 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      5967    0.040    0.000    0.040    0.000 :0(BFMatcher)
#       276    0.001    0.000    0.001    0.000 :0(SIFT)
#        15    0.000    0.000    0.000    0.000 :0(StringIO)
#        28    0.000    0.000    0.000    0.000 :0(__import__)
#        44    0.000    0.000    0.000    0.000 :0(__setstate__)
#        24    0.000    0.000    0.000    0.000 :0(_reconstruct)
#        39    0.000    0.000    0.001    0.000 :0(all)
#     13244    0.040    0.000    0.040    0.000 :0(append)
#         1    0.000    0.000    0.000    0.000 :0(arange)
#      5967    0.050    0.000    0.050    0.000 :0(argsort)
#    205828    1.306    0.000    1.307    0.000 :0(array)
#     88916    0.346    0.000    0.346    0.000 :0(block)
#        39    0.000    0.000    0.000    0.000 :0(chr)
#        89    0.001    0.000    0.001    0.000 :0(close)
#       250    0.005    0.000    0.005    0.000 :0(computeCorrespondEpilines)
#        12    0.000    0.000    0.000    0.000 :0(copy)
#       180    0.003    0.000    0.003    0.000 :0(crc32)
#        74    0.036    0.000    0.036    0.000 :0(decode)
#       276    1.788    0.006    1.788    0.006 :0(detectAndCompute)
#    210566    2.105    0.000    2.105    0.000 :0(dot)
#        39    0.000    0.000    0.000    0.000 :0(empty)
#        18    0.001    0.000    0.001    0.000 :0(encode)
#       107    0.000    0.000    0.000    0.000 :0(endswith)
#       210    0.005    0.000    0.005    0.000 :0(eval)
#        39    0.001    0.000    0.001    0.000 :0(expr)
#         6    0.028    0.005    0.028    0.005 :0(fill)
#        39    0.000    0.000    0.000    0.000 :0(find)
#        43    0.000    0.000    0.000    0.000 :0(frombuffer)
#     64760    1.559    0.000    4.226    0.000 :0(get)
#     43452    0.194    0.000    0.194    0.000 :0(get_neighbor)
#      3032    0.009    0.000    0.009    0.000 :0(getattr)
#      3393    0.010    0.000    0.010    0.000 :0(hasattr)
#         3    0.107    0.036    0.107    0.036 :0(imread)
#        39    0.000    0.000    0.000    0.000 :0(insert)
#      6704    0.025    0.000    0.025    0.000 :0(isinstance)
#        39    0.000    0.000    0.000    0.000 :0(items)
#        10    0.000    0.000    0.000    0.000 :0(iteritems)
#         3    0.000    0.000    0.000    0.000 :0(join)
#        40    0.000    0.000    0.000    0.000 :0(keys)
#      5967    0.540    0.000    0.540    0.000 :0(knnMatch)
#    236254    0.836    0.000    0.836    0.000 :0(len)
#        10    0.002    0.000    0.002    0.000 :0(listdir)
# 21769/21739    0.103    0.000    0.933    0.000 :0(map)
#      2370    0.008    0.000    0.008    0.000 :0(match)
#       111    0.000    0.000    0.000    0.000 :0(max)
#       184    0.001    0.000    0.001    0.000 :0(min)
#         4    0.000    0.000    0.000    0.000 :0(new)
#         8    0.000    0.000    0.000    0.000 :0(newObj)
#      5964    0.032    0.000    0.032    0.000 :0(offset)
#        11    0.000    0.000    0.000    0.000 :0(open)
#        15    0.000    0.000    0.000    0.000 :0(pixel_access)
#       124    0.000    0.000    0.000    0.000 :0(pop)
#        11    0.000    0.000    0.000    0.000 :0(proxy)
#      1426    0.005    0.000    0.005    0.000 :0(range)
#         6    0.000    0.000    0.000    0.000 :0(raw_decoder)
#         3    0.000    0.000    0.000    0.000 :0(raw_encoder)
#      1654    0.007    0.000    0.007    0.000 :0(read)
#       768    0.002    0.000    0.002    0.000 :0(readline)
#      6461    0.107    0.000    0.107    0.000 :0(reduce)
#        11    0.000    0.000    0.000    0.000 :0(replace)
#      6389    0.038    0.000    0.038    0.000 :0(reshape)
#         3    0.004    0.001    0.004    0.001 :0(resize)
#       133    0.001    0.000    0.001    0.000 :0(seek)
#         9    0.000    0.000    0.000    0.000 :0(setimage)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#        49    0.000    0.000    0.000    0.000 :0(sorted)
#        39    0.001    0.000    0.001    0.000 :0(st2tuple)
#       144    0.000    0.000    0.000    0.000 :0(startswith)
#         4    0.000    0.000    0.000    0.000 :0(stat)
#         3    0.142    0.047    0.142    0.047 :0(stretch)
#      6159    0.041    0.000    0.183    0.000 :0(sum)
#        11    0.000    0.000    0.000    0.000 :0(tell)
#       178    0.001    0.000    0.001    0.000 :0(unpack)
#         1    0.000    0.000    0.000    0.000 :0(values)
#      6143    0.066    0.000    0.066    0.000 :0(zip)
#     211/1    0.008    0.000   18.049   18.049 <string>:1(<module>)
#         6    0.000    0.000    0.146    0.024 Image.py:1395(resize)
#         6    0.000    0.000    0.146    0.024 Image.py:1637(thumbnail)
#         6    0.000    0.000    0.028    0.005 Image.py:1862(new)
#         6    0.000    0.000    0.064    0.011 Image.py:1890(frombytes)
#         6    0.000    0.000    0.064    0.011 Image.py:1938(frombuffer)
#         6    0.000    0.000    0.064    0.011 Image.py:1999(fromarray)
#         3    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         6    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         3    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#        18    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#        12    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         6    0.000    0.000    0.001    0.000 Image.py:528(__getattr__)
#         3    0.000    0.000    0.001    0.000 Image.py:539(tobytes)
#         6    0.000    0.000    0.036    0.006 Image.py:603(frombytes)
#        15    0.000    0.000    0.000    0.000 Image.py:637(load)
#         6    0.000    0.000    0.000    0.000 Image.py:895(draft)
#       248    0.002    0.000    0.010    0.000 _methods.py:19(_amin)
#      6139    0.045    0.000    0.142    0.000 _methods.py:23(_sum)
#        39    0.000    0.000    0.001    0.000 _methods.py:35(_all)
#         6    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#        39    0.000    0.000    0.000    0.000 ast.py:1310(__init__)
#       210    0.001    0.000    0.001    0.000 ast.py:361(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:404(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:41(__init__)
#        39    0.000    0.000    0.000    0.000 ast.py:47(getChildNodes)
#        39    0.000    0.000    0.000    0.000 ast.py:984(__init__)
#      6139    0.036    0.000    0.059    0.000 base.py:702(isspmatrix)
#      6139    2.206    0.000    8.812    0.001 fastmatch.py:113(match_position)
#         3    0.000    0.000    0.522    0.174 fastmatch.py:27(match)
#        60    0.002    0.000    0.002    0.000 fastmatch.py:37(get_matches)
#      7991    1.221    0.000   11.393    0.001 fastmatch.py:45(do_iter)
#     43452    0.450    0.000    0.815    0.000 fastmatch.py:72(get_neighbor)
#         3    0.002    0.001    0.522    0.174 fastmatch.py:78(match_thumbs)
#        10    0.007    0.001    0.016    0.002 fnmatch.py:45(filter)
#        39    0.000    0.000    0.006    0.000 format.py:179(read_magic)
#        39    0.002    0.000    0.189    0.005 format.py:291(read_array_header_1_0)
#        39    0.003    0.000    0.209    0.005 format.py:412(read_array)
#       160    0.003    0.000    0.021    0.000 format.py:589(_read_bytes)
#        39    0.000    0.000    0.003    0.000 fromnumeric.py:1842(all)
#       248    0.004    0.000    0.014    0.000 fromnumeric.py:2132(amin)
#      5967    0.040    0.000    0.090    0.000 fromnumeric.py:792(argsort)
#         1    0.000    0.000    0.000    0.000 function_base.py:8(linspace)
#         4    0.000    0.000    0.000    0.000 genericpath.py:26(isfile)
#         4    0.000    0.000    0.000    0.000 hashlib.py:113(__hash_new)
#         6    0.000    0.000    0.064    0.011 imaging.py:21(__init__)
#         3    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         6    0.000    0.000    0.064    0.011 imaging.py:43(from_array)
#         9    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         3    0.000    0.000    0.146    0.049 imaging.py:52(scale)
#         6    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         3    0.000    0.000    0.181    0.060 imaging.py:80(get_thumbnail)
#         3    0.000    0.000    0.031    0.010 imaging.py:84(get_size)
#         3    0.000    0.000    0.107    0.036 imaging.py:94(open_cv)
#         3    0.000    0.000    0.107    0.036 imaging.py:97(open_img)
#       276    0.003    0.000    1.793    0.006 matchutil.py:22(get_features)
#        11    0.000    0.000    0.000    0.000 npyio.py:119(__init__)
#        11    0.000    0.000    0.006    0.001 npyio.py:128(zipfile_factory)
#        11    0.000    0.000    0.007    0.001 npyio.py:189(__init__)
#        11    0.000    0.000    0.001    0.000 npyio.py:213(close)
#        11    0.000    0.000    0.001    0.000 npyio.py:226(__del__)
#        39    0.001    0.000    0.224    0.006 npyio.py:229(__getitem__)
#        11    0.001    0.000    0.009    0.001 npyio.py:284(load)
#     12278    0.080    0.000    0.166    0.000 numeric.py:392(asarray)
#     12317    0.077    0.000    0.129    0.000 numeric.py:462(asanyarray)
#         4    0.000    0.000    0.000    0.000 pickle.py:1027(load_dict)
#        28    0.000    0.000    0.001    0.000 pickle.py:1087(load_global)
#        28    0.000    0.000    0.001    0.000 pickle.py:1122(find_class)
#        44    0.000    0.000    0.001    0.000 pickle.py:1129(load_reduce)
#       112    0.001    0.000    0.002    0.000 pickle.py:1150(load_get)
#       300    0.002    0.000    0.003    0.000 pickle.py:1164(load_put)
#        16    0.000    0.000    0.000    0.000 pickle.py:1193(load_setitem)
#        44    0.001    0.000    0.001    0.000 pickle.py:1211(load_build)
#       160    0.001    0.000    0.001    0.000 pickle.py:1250(load_mark)
#         4    0.000    0.000    0.000    0.000 pickle.py:1254(load_stop)
#         4    0.000    0.000    0.033    0.008 pickle.py:1380(loads)
#         4    0.000    0.000    0.000    0.000 pickle.py:829(__init__)
#         4    0.000    0.000    0.000    0.000 pickle.py:83(__init__)
#         4    0.007    0.002    0.033    0.008 pickle.py:845(load)
#       160    0.001    0.000    0.002    0.000 pickle.py:870(marker)
#        28    0.000    0.000    0.000    0.000 pickle.py:899(load_none)
#       228    0.002    0.000    0.004    0.000 pickle.py:911(load_int)
#         4    0.000    0.000    0.000    0.000 pickle.py:953(load_float)
#        68    0.002    0.000    0.005    0.000 pickle.py:961(load_string)
#       156    0.001    0.000    0.003    0.000 pickle.py:993(load_tuple)
#        10    0.000    0.000    0.000    0.000 posixpath.py:51(normcase)
#         0    0.000             0.000          profile:0(profiler)
#         1    0.000    0.000   18.049   18.049 profile:0(turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options))
#        39    0.000    0.000    0.000    0.000 py3k.py:61(isfileobj)
#      6139    0.153    0.000    0.293    0.000 shape_base.py:60(atleast_2d)
#      6139    0.124    0.000    0.275    0.000 shape_base.py:8(atleast_1d)
#         4    0.000    0.000    0.000    0.000 stat.py:24(S_IFMT)
#         4    0.000    0.000    0.000    0.000 stat.py:49(S_ISREG)
#        39    0.018    0.000    0.036    0.001 transformer.py:104(__init__)
#   1709/39    0.023    0.000    0.125    0.003 transformer.py:1077(com_binary)
#        39    0.001    0.000    0.128    0.003 transformer.py:120(transform)
#        39    0.002    0.000    0.111    0.003 transformer.py:1211(com_dictorsetmaker)
#        39    0.001    0.000    0.130    0.003 transformer.py:130(parseexpr)
#        39    0.000    0.000    0.127    0.003 transformer.py:145(compile_node)
#        39    0.000    0.000    0.126    0.003 transformer.py:191(eval_input)
#        39    0.000    0.000    0.166    0.004 transformer.py:49(parse)
#     74/39    0.001    0.000    0.126    0.003 transformer.py:574(testlist)
#        35    0.000    0.000    0.024    0.001 transformer.py:584(testlist_comp)
#    327/39    0.004    0.000    0.125    0.003 transformer.py:592(test)
#    327/39    0.003    0.000    0.124    0.003 transformer.py:606(or_test)
#    327/39    0.002    0.000    0.122    0.003 transformer.py:613(and_test)
#    327/39    0.003    0.000    0.121    0.003 transformer.py:617(not_test)
#    327/39    0.003    0.000    0.120    0.003 transformer.py:624(comparison)
#    327/39    0.002    0.000    0.120    0.003 transformer.py:657(expr)
#    327/39    0.002    0.000    0.119    0.003 transformer.py:661(xor_expr)
#    327/39    0.002    0.000    0.118    0.003 transformer.py:665(and_expr)
#    327/39    0.004    0.000    0.117    0.003 transformer.py:669(shift_expr)
#    327/39    0.004    0.000    0.116    0.003 transformer.py:682(arith_expr)
#    327/39    0.004    0.000    0.115    0.003 transformer.py:694(term)
#    327/39    0.003    0.000    0.114    0.003 transformer.py:712(factor)
#     70/35    0.001    0.000    0.001    0.000 transformer.py:72(extractLineNo)
#    327/39    0.004    0.000    0.113    0.003 transformer.py:725(power)
#    327/39    0.002    0.000    0.112    0.003 transformer.py:738(atom)
#        39    0.000    0.000    0.024    0.001 transformer.py:741(atom_lpar)
#        39    0.000    0.000    0.112    0.003 transformer.py:751(atom_lbrace)
#        54    0.001    0.000    0.002    0.000 transformer.py:759(atom_number)
#       156    0.001    0.000    0.005    0.000 transformer.py:764(decode_literal)
#       156    0.002    0.000    0.007    0.000 transformer.py:775(atom_string)
#        39    0.000    0.000    0.000    0.000 transformer.py:781(atom_name)
#      2055    0.006    0.000    0.006    0.000 transformer.py:797(lookup_node)
#   2597/39    0.017    0.000    0.126    0.003 transformer.py:800(com_node)
#        10    0.000    0.000    0.018    0.002 turntable.py:106(get_turntable_path)
#         3    0.000    0.000    0.020    0.007 turntable.py:161(get_fundamental_matrix)
#         1    0.013    0.013    5.776    5.776 turntable.py:220(match_distances)
#      2214    1.261    0.001    5.675    0.003 turntable.py:250(calc_match_distances)
#    210566    2.270    0.000    4.375    0.000 turntable.py:258(dist)
#       250    0.011    0.000    0.018    0.000 turntable.py:262(get_lines)
#        10    0.000    0.000    0.000    0.000 turntable.py:289(get_image_set)
#         1    0.001    0.001   18.041   18.041 turntable.py:32(evaluate)
#        60    0.000    0.000    0.000    0.000 turntable.py:45(<lambda>)
#         3    0.000    0.000    0.016    0.005 turntable.py:48(get_path)
#         3    0.001    0.000    0.830    0.277 turntable.py:58(get_match_fun)
#        80    0.001    0.000    0.003    0.000 turntable.py:67(<genexpr>)
#        20    0.032    0.002   11.428    0.571 turntable.py:67(<lambda>)
#         1    0.003    0.003    0.003    0.003 turntable.py:71(<dictcomp>)
#        20    0.003    0.000    0.003    0.000 turntable.py:75(<lambda>)
#        39    0.000    0.000    0.000    0.000 utils.py:1008(visitName)
#        39    0.001    0.000    0.176    0.005 utils.py:1072(safe_eval)
#    366/39    0.004    0.000    0.008    0.000 utils.py:977(visit)
#        39    0.000    0.000    0.007    0.000 utils.py:986(visitExpression)
#       210    0.001    0.000    0.001    0.000 utils.py:990(visitConst)
#        39    0.001    0.000    0.006    0.000 utils.py:993(visitDict)
#        39    0.000    0.000    0.001    0.000 utils.py:996(visitTuple)
#      6139    0.080    0.000    0.263    0.000 validation.py:23(_assert_all_finite)
#      6139    0.123    0.000    0.827    0.000 validation.py:86(array2d)
#        39    0.000    0.000    0.000    0.000 warnings.py:318(__init__)
#        39    0.000    0.000    0.000    0.000 warnings.py:339(__enter__)
#        39    0.000    0.000    0.000    0.000 warnings.py:355(__exit__)
#        39    0.000    0.000    0.001    0.000 warnings.py:74(simplefilter)
#        11    0.000    0.000    0.000    0.000 zipfile.py:1247(__del__)
#        22    0.000    0.000    0.000    0.000 zipfile.py:1251(close)
#        11    0.000    0.000    0.001    0.000 zipfile.py:158(_EndRecData64)
#        11    0.000    0.000    0.001    0.000 zipfile.py:201(_EndRecData)
#        39    0.000    0.000    0.001    0.000 zipfile.py:287(__init__)
#        39    0.000    0.000    0.000    0.000 zipfile.py:377(_decodeFilename)
#        39    0.000    0.000    0.000    0.000 zipfile.py:383(_decodeExtra)
#        78    0.001    0.000    0.002    0.000 zipfile.py:515(__init__)
#       199    0.004    0.000    0.020    0.000 zipfile.py:621(read)
#       102    0.001    0.000    0.004    0.000 zipfile.py:639(_update_crc)
#       199    0.006    0.000    0.014    0.000 zipfile.py:649(read1)
#        78    0.001    0.000    0.001    0.000 zipfile.py:701(close)
#        11    0.000    0.000    0.006    0.001 zipfile.py:726(__init__)
#        11    0.002    0.000    0.006    0.001 zipfile.py:803(_RealGetContents)
#        11    0.000    0.000    0.000    0.000 zipfile.py:872(namelist)
#        78    0.001    0.000    0.001    0.000 zipfile.py:904(getinfo)
#        78    0.003    0.000    0.008    0.000 zipfile.py:937(open)

# %%
{ "a" : 1, "b" : 2}.values()
# Out:
# [1, 2]
