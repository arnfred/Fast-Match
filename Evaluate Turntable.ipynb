# %%
# %load_ext autoreload
# %autoreload 2

import turntable
import turntable_ground_truth
from cache import Metric_Cache, Grid_Cache
import fastmatch
import imaging
import cv2
import figures
import profile
import cProfile
import pandas

# %%
options = {"distance_threshold" : 5 }
flowerlamp_gt = turntable_ground_truth.ground_truth((0, 25), "FlowerLamp", options = options)
flowerlamp_gt["nb_correspondences"]
# Out:
# 9863

# %%
options = {"evaluate_verbose" : True,
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
            "grid_margin" : 40,
            "radius" : 75,
            "thumb_size" : (200, 200)}
cProfile.run('turntable.evaluate(fastmatch.match, \
                             (0, 25), \
                             "FlowerLamp", \
                             numpy.linspace(0.5, 1.2, 15), \
                             ground_truth = flowerlamp_gt, \
                             options = options)')
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
#  515631 function calls (509634 primitive calls) in 7.079 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        45    0.000    0.000    0.000    0.000 <ipython-input-5-5f0d1a2aef27>:2(<lambda>)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         6    0.000    0.000    0.038    0.006 Image.py:1395(resize)
#         6    0.000    0.000    0.038    0.006 Image.py:1637(thumbnail)
#         6    0.000    0.000    0.037    0.006 Image.py:1862(new)
#         6    0.000    0.000    0.074    0.012 Image.py:1890(frombytes)
#         6    0.000    0.000    0.074    0.012 Image.py:1938(frombuffer)
#         6    0.000    0.000    0.074    0.012 Image.py:1999(fromarray)
#         3    0.000    0.000    0.000    0.000 Image.py:251(_conv_type_shape)
#         6    0.000    0.000    0.000    0.000 Image.py:385(_getdecoder)
#         3    0.000    0.000    0.000    0.000 Image.py:401(_getencoder)
#        18    0.000    0.000    0.000    0.000 Image.py:468(__init__)
#        12    0.000    0.000    0.000    0.000 Image.py:480(_new)
#         6    0.000    0.000    0.000    0.000 Image.py:528(__getattr__)
#         3    0.000    0.000    0.000    0.000 Image.py:539(tobytes)
#         6    0.000    0.000    0.037    0.006 Image.py:603(frombytes)
#        15    0.000    0.000    0.000    0.000 Image.py:637(load)
#         6    0.000    0.000    0.000    0.000 Image.py:895(draft)
#         2    0.000    0.000    0.000    0.000 __init__.py:138(itervalues)
#      4258    0.007    0.000    0.053    0.000 _methods.py:23(_sum)
#        11    0.000    0.000    0.000    0.000 _methods.py:27(_prod)
#         6    0.000    0.000    0.000    0.000 _methods.py:31(_any)
#        29    0.000    0.000    0.000    0.000 _methods.py:35(_all)
#         6    0.000    0.000    0.000    0.000 _util.py:4(isStringType)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         5    0.000    0.000    0.000    0.000 abc.py:128(__instancecheck__)
#        27    0.000    0.000    0.000    0.000 ast.py:1310(__init__)
#       144    0.000    0.000    0.000    0.000 ast.py:361(__init__)
#        27    0.000    0.000    0.000    0.000 ast.py:404(__init__)
#        27    0.000    0.000    0.000    0.000 ast.py:41(__init__)
#        27    0.000    0.000    0.000    0.000 ast.py:47(getChildNodes)
#        27    0.000    0.000    0.000    0.000 ast.py:984(__init__)
#         2    0.000    0.000    0.000    0.000 base.py:62(_constructor)
#      4254    0.004    0.000    0.009    0.000 base.py:702(isspmatrix)
#      4254    0.005    0.000    2.085    0.000 cache.pyx:103(get_cell)
#     51098    0.173    0.000    0.173    0.000 cache.pyx:117(center)
#       171    0.003    0.000    2.080    0.012 cache.pyx:125(cache)
#         3    0.000    0.000    0.030    0.010 cache.pyx:154(__init__)
#      4254    1.005    0.000    1.240    0.000 cache.pyx:174(get)
#         3    0.000    0.000    0.030    0.010 cache.pyx:213(load)
#         3    0.000    0.000    0.000    0.000 cache.pyx:33(__init__)
#      4254    0.005    0.000    2.096    0.000 cache.pyx:51(get)
#      4239    0.002    0.000    0.004    0.000 cache.pyx:64(offset)
#     25549    0.309    0.000    0.639    0.000 cache.pyx:72(get_neighbor)
#     64805    0.034    0.000    0.034    0.000 cache.pyx:96(block)
#        14    0.000    0.000    0.000    0.000 common.py:111(isnull)
#         2    0.000    0.000    0.000    0.000 common.py:1183(_fill_zeros)
#        14    0.000    0.000    0.000    0.000 common.py:128(_isnull_new)
#         8    0.000    0.000    0.000    0.000 common.py:1544(_values_from_object)
#        17    0.000    0.000    0.000    0.000 common.py:1616(_possibly_castable)
#        19    0.000    0.000    0.000    0.000 common.py:1641(_possibly_cast_to_datetime)
#         3    0.000    0.000    0.000    0.000 common.py:1742(_is_bool_indexer)
#         3    0.000    0.000    0.000    0.000 common.py:1807(_try_sort)
#         5    0.000    0.000    0.000    0.000 common.py:1986(_asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 common.py:199(_isnull_ndarraylike)
#         1    0.000    0.000    0.000    0.000 common.py:2039(is_bool)
#         5    0.000    0.000    0.000    0.000 common.py:2043(is_integer)
#         2    0.000    0.000    0.000    0.000 common.py:2064(is_integer_dtype)
#        14    0.000    0.000    0.000    0.000 common.py:2083(is_datetime64_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:2103(is_timedelta64_dtype)
#        15    0.000    0.000    0.000    0.000 common.py:2155(is_list_like)
#         2    0.000    0.000    0.000    0.000 common.py:2160(_is_sequence)
#         6    0.000    0.000    0.000    0.000 common.py:258(notnull)
#         1    0.000    0.000    0.000    0.000 common.py:2731(_maybe_match_name)
#        40    0.000    0.000    0.000    0.000 common.py:58(_check)
#         1    0.000    0.000    0.000    0.000 common.py:848(_infer_dtype_from_scalar)
#         2    0.000    0.000    0.000    0.000 common.py:968(_maybe_upcast_putmask)
#         2    0.000    0.000    0.000    0.000 expressions.py:157(evaluate)
#         2    0.000    0.000    0.000    0.000 expressions.py:60(_evaluate_standard)
#         3    0.001    0.000    0.158    0.053 fastmatch.pyx:107(match_thumbs)
#      4254    1.804    0.000    5.144    0.001 fastmatch.pyx:145(match_position)
#         3    0.000    0.000    0.158    0.053 fastmatch.pyx:32(match)
#        45    0.004    0.000    6.623    0.147 fastmatch.pyx:48(get_matches)
#        45    0.525    0.012    6.619    0.147 fastmatch.pyx:56(do_iter)
#      4254    0.285    0.000    0.929    0.000 fastmatch.pyx:92(get_neighbors)
#        15    0.001    0.000    0.002    0.000 fnmatch.py:45(filter)
#        27    0.000    0.000    0.001    0.000 format.py:179(read_magic)
#        27    0.001    0.000    0.018    0.001 format.py:291(read_array_header_1_0)
#        27    0.001    0.000    0.022    0.001 format.py:412(read_array)
#       111    0.000    0.000    0.003    0.000 format.py:589(_read_bytes)
#         6    0.000    0.000    0.001    0.000 frame.py:1562(icol)
#         6    0.000    0.000    0.001    0.000 frame.py:1565(_ixs)
#         4    0.000    0.000    0.000    0.000 frame.py:181(_constructor)
#         5    0.000    0.000    0.002    0.000 frame.py:187(__init__)
#         3    0.000    0.000    0.002    0.001 frame.py:277(_init_dict)
#         2    0.000    0.000    0.157    0.078 frame.py:3237(apply)
#         2    0.000    0.000    0.156    0.078 frame.py:3342(_apply_standard)
#         8    0.000    0.000    0.001    0.000 frame.py:3369(<genexpr>)
#         2    0.000    0.000    0.000    0.000 frame.py:369(shape)
#         2    0.000    0.000    0.001    0.000 frame.py:3959(_reduce)
#         2    0.000    0.000    0.000    0.000 frame.py:3962(<lambda>)
#         4    0.000    0.000    0.000    0.000 frame.py:4092(_get_agg_axis)
#         3    0.000    0.000    0.001    0.000 frame.py:4456(_arrays_to_mgr)
#         3    0.000    0.000    0.000    0.000 frame.py:4476(extract_index)
#         3    0.000    0.000    0.000    0.000 frame.py:4752(_homogenize)
#        27    0.000    0.000    0.001    0.000 fromnumeric.py:1842(all)
#        11    0.000    0.000    0.000    0.000 fromnumeric.py:2249(prod)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:792(argsort)
#         1    0.000    0.000    0.000    0.000 function_base.py:8(linspace)
#         6    0.000    0.000    0.000    0.000 generic.py:1014(_set_as_cached)
#         2    0.000    0.000    0.000    0.000 generic.py:105(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 generic.py:1061(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 generic.py:118(_init_mgr)
#        10    0.000    0.000    0.000    0.000 generic.py:1785(__finalize__)
#        12    0.000    0.000    0.000    0.000 generic.py:1817(__setattr__)
#         4    0.000    0.000    0.000    0.000 generic.py:1842(_consolidate_inplace)
#         4    0.000    0.000    0.000    0.000 generic.py:1843(<lambda>)
#         2    0.000    0.000    0.000    0.000 generic.py:1870(_is_mixed_type)
#         2    0.000    0.000    0.000    0.000 generic.py:1872(<lambda>)
#         6    0.000    0.000    0.000    0.000 generic.py:1885(_protect_consolidate)
#         4    0.000    0.000    0.000    0.000 generic.py:1902(as_matrix)
#         4    0.000    0.000    0.000    0.000 generic.py:1929(values)
#         2    0.000    0.000    0.000    0.000 generic.py:2039(convert_objects)
#         4    0.000    0.000    0.000    0.000 generic.py:284(_get_axis_number)
#         2    0.000    0.000    0.000    0.000 generic.py:297(_get_axis_name)
#         2    0.000    0.000    0.000    0.000 generic.py:310(_get_axis)
#         2    0.000    0.000    0.001    0.000 generic.py:3478(stat_func)
#         2    0.000    0.000    0.000    0.000 generic.py:395(_set_axis)
#        27    0.000    0.000    0.000    0.000 generic.py:88(__init__)
#         3    0.000    0.000    0.000    0.000 genericpath.py:26(isfile)
#         3    0.000    0.000    0.000    0.000 hashlib.py:113(__hash_new)
#         6    0.000    0.000    0.074    0.012 imaging.py:21(__init__)
#         3    0.000    0.000    0.000    0.000 imaging.py:31(resize)
#         6    0.000    0.000    0.074    0.012 imaging.py:43(from_array)
#         9    0.000    0.000    0.000    0.000 imaging.py:44(get_size)
#         3    0.000    0.000    0.038    0.013 imaging.py:52(scale)
#         6    0.000    0.000    0.000    0.000 imaging.py:54(<lambda>)
#         3    0.000    0.000    0.078    0.026 imaging.py:80(get_thumbnail)
#         3    0.000    0.000    0.035    0.012 imaging.py:84(get_size)
#         3    0.000    0.000    0.103    0.034 imaging.py:94(open_cv)
#         3    0.000    0.000    0.103    0.034 imaging.py:97(open_img)
#         6    0.000    0.000    0.000    0.000 index.py:1009(get_loc)
#         3    0.000    0.000    0.000    0.000 index.py:1170(isin)
#         3    0.000    0.000    0.000    0.000 index.py:1186(_array_values)
#         1    0.000    0.000    0.000    0.000 index.py:1246(join)
#         1    0.000    0.000    0.000    0.000 index.py:1425(_join_monotonic)
#         2    0.000    0.000    0.000    0.000 index.py:163(is_)
#         8    0.000    0.000    0.000    0.000 index.py:1659(__new__)
#         2    0.000    0.000    0.000    0.000 index.py:1707(equals)
#         1    0.000    0.000    0.000    0.000 index.py:1752(__new__)
#         1    0.000    0.000    0.000    0.000 index.py:1781(inferred_type)
#         1    0.000    0.000    0.000    0.000 index.py:1785(astype)
#        10    0.000    0.000    0.000    0.000 index.py:182(_reset_identity)
#         6    0.000    0.000    0.000    0.000 index.py:1831(equals)
#        23    0.000    0.000    0.000    0.000 index.py:186(view)
#         9    0.000    0.000    0.000    0.000 index.py:205(_coerce_to_ndarray)
#        10    0.000    0.000    0.000    0.000 index.py:220(__array_finalize__)
#         1    0.000    0.000    0.000    0.000 index.py:301(dtype)
#         1    0.000    0.000    0.000    0.000 index.py:314(_set_names)
#        44    0.000    0.000    0.000    0.000 index.py:3522(_ensure_index)
#         1    0.000    0.000    0.000    0.000 index.py:3560(_validate_join_method)
#         3    0.000    0.000    0.000    0.000 index.py:3585(_union_indexes)
#         3    0.000    0.000    0.000    0.000 index.py:3626(_sanitize_and_check)
#         2    0.000    0.000    0.000    0.000 index.py:364(_has_complex_internals)
#        14    0.000    0.000    0.000    0.000 index.py:392(values)
#         2    0.000    0.000    0.000    0.000 index.py:402(is_monotonic)
#         4    0.000    0.000    0.000    0.000 index.py:409(is_unique)
#         5    0.000    0.000    0.000    0.000 index.py:558(_engine)
#         6    0.000    0.000    0.000    0.000 index.py:561(<lambda>)
#         1    0.000    0.000    0.000    0.000 index.py:578(is_all_dates)
#         6    0.000    0.000    0.000    0.000 index.py:582(__iter__)
#        12    0.000    0.000    0.000    0.000 index.py:604(__contains__)
#        21    0.000    0.000    0.000    0.000 index.py:615(__getitem__)
#         2    0.000    0.000    0.000    0.000 index.py:682(take)
#         4    0.000    0.000    0.000    0.000 index.py:863(union)
#         8    0.000    0.000    0.001    0.000 index.py:98(__new__)
#        11    0.000    0.000    0.000    0.000 internals.py:1350(__init__)
#        25    0.000    0.000    0.000    0.000 internals.py:142(set_ref_locs)
#         2    0.000    0.000    0.000    0.000 internals.py:151(set_ref_items)
#         6    0.000    0.000    0.000    0.000 internals.py:180(__contains__)
#        25    0.000    0.000    0.001    0.000 internals.py:1944(make_block)
#         5    0.000    0.000    0.000    0.000 internals.py:2018(__init__)
#         3    0.000    0.000    0.000    0.000 internals.py:2059(shape)
#         9    0.000    0.000    0.000    0.000 internals.py:2062(<genexpr>)
#         5    0.000    0.000    0.000    0.000 internals.py:2065(ndim)
#         2    0.000    0.000    0.000    0.000 internals.py:2071(_set_axis)
#         2    0.000    0.000    0.000    0.000 internals.py:2084(set_axis)
#        49    0.000    0.000    0.000    0.000 internals.py:210(dtype)
#         2    0.000    0.000    0.000    0.000 internals.py:2100(_reset_ref_locs)
#         2    0.000    0.000    0.000    0.000 internals.py:2117(_rebuild_ref_locs)
#         4    0.000    0.000    0.000    0.000 internals.py:2131(_set_ref_locs)
#         5    0.000    0.000    0.000    0.000 internals.py:214(ftype)
#        47    0.000    0.000    0.000    0.000 internals.py:2239(_get_items)
#         6    0.000    0.000    0.000    0.000 internals.py:2313(__len__)
#         3    0.000    0.000    0.000    0.000 internals.py:2328(_verify_integrity)
#         6    0.000    0.000    0.000    0.000 internals.py:2330(<genexpr>)
#         2    0.000    0.000    0.000    0.000 internals.py:2344(apply)
#         2    0.000    0.000    0.000    0.000 internals.py:2418(convert)
#        11    0.000    0.000    0.000    0.000 internals.py:2492(is_consolidated)
#         5    0.000    0.000    0.000    0.000 internals.py:2500(_consolidate_check)
#         5    0.000    0.000    0.000    0.000 internals.py:2506(_set_has_sparse)
#        10    0.000    0.000    0.000    0.000 internals.py:2507(<genexpr>)
#         2    0.000    0.000    0.000    0.000 internals.py:2509(is_mixed_type)
#         4    0.000    0.000    0.000    0.000 internals.py:2706(as_matrix)
#         4    0.000    0.000    0.000    0.000 internals.py:2837(consolidate)
#         7    0.000    0.000    0.000    0.000 internals.py:2852(_consolidate_inplace)
#         6    0.000    0.000    0.000    0.000 internals.py:2866(get)
#         6    0.000    0.000    0.000    0.000 internals.py:2903(iget)
#         6    0.000    0.000    0.000    0.000 internals.py:293(get)
#         6    0.000    0.000    0.000    0.000 internals.py:3184(_find_block)
#         6    0.000    0.000    0.000    0.000 internals.py:3190(_check_have)
#        22    0.000    0.000    0.001    0.000 internals.py:3571(__init__)
#        44    0.000    0.000    0.000    0.000 internals.py:3694(dtype)
#        28    0.000    0.000    0.000    0.000 internals.py:3702(values)
#         3    0.000    0.000    0.001    0.000 internals.py:3752(create_block_manager_from_arrays)
#         3    0.000    0.000    0.001    0.000 internals.py:3771(form_blocks)
#         1    0.000    0.000    0.000    0.000 internals.py:3868(_simple_blockify)
#         2    0.000    0.000    0.000    0.000 internals.py:3884(_multi_blockify)
#         6    0.000    0.000    0.000    0.000 internals.py:3888(<lambda>)
#         3    0.000    0.000    0.000    0.000 internals.py:3923(_stack_arrays)
#         9    0.000    0.000    0.000    0.000 internals.py:3926(_asarray_compat)
#         3    0.000    0.000    0.000    0.000 internals.py:3932(_shape_compat)
#         2    0.000    0.000    0.000    0.000 internals.py:462(convert)
#        25    0.000    0.000    0.000    0.000 internals.py:53(__init__)
#         2    0.000    0.000    0.000    0.000 internals.py:81(_is_single_block)
#         4    0.000    0.000    0.000    0.000 internals.py:903(get_values)
#         2    0.000    0.000    0.000    0.000 internals.py:94(ref_locs)
#         2    0.000    0.000    0.000    0.000 iostream.py:189(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:90(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:99(_check_mp_mode)
#       174    0.001    0.000    2.121    0.012 matchutil.py:22(get_features)
#         2    0.000    0.000    0.000    0.000 nanops.py:111(_get_fill_value)
#         2    0.000    0.000    0.000    0.000 nanops.py:134(_get_values)
#         2    0.000    0.000    0.000    0.000 nanops.py:180(_na_ok_dtype)
#         2    0.000    0.000    0.000    0.000 nanops.py:185(_view_if_needed)
#         2    0.000    0.000    0.000    0.000 nanops.py:228(nansum)
#         6    0.000    0.000    0.000    0.000 nanops.py:31(check)
#         2    0.000    0.000    0.000    0.000 nanops.py:36(_f)
#         8    0.000    0.000    0.000    0.000 nanops.py:39(<genexpr>)
#         2    0.000    0.000    0.000    0.000 nanops.py:512(_maybe_null_out)
#         2    0.000    0.000    0.000    0.000 nanops.py:61(f)
#         6    0.000    0.000    0.000    0.000 npyio.py:119(__init__)
#         6    0.000    0.000    0.001    0.000 npyio.py:128(zipfile_factory)
#         6    0.000    0.000    0.001    0.000 npyio.py:189(__init__)
#         6    0.000    0.000    0.000    0.000 npyio.py:213(close)
#         6    0.000    0.000    0.000    0.000 npyio.py:226(__del__)
#        27    0.000    0.000    0.024    0.001 npyio.py:229(__getitem__)
#         6    0.000    0.000    0.001    0.000 npyio.py:284(load)
#     25549    0.041    0.000    0.156    0.000 numeric.py:136(ones)
#        45    0.000    0.000    0.000    0.000 numeric.py:1810(isscalar)
#         2    0.000    0.000    0.000    0.000 numeric.py:2222(array_equal)
#      8535    0.009    0.000    0.039    0.000 numeric.py:392(asarray)
#      8535    0.009    0.000    0.021    0.000 numeric.py:462(asanyarray)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:667(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:735(issubdtype)
#         2    0.000    0.000    0.000    0.000 ops.py:412(maybe_convert_for_time_op)
#         2    0.000    0.000    0.000    0.000 ops.py:440(na_op)
#         2    0.000    0.000    0.000    0.000 ops.py:460(wrapper)
#         2    0.000    0.000    0.000    0.000 ops.py:469(<lambda>)
#         3    0.000    0.000    0.000    0.000 pickle.py:1027(load_dict)
#        21    0.000    0.000    0.000    0.000 pickle.py:1087(load_global)
#        21    0.000    0.000    0.000    0.000 pickle.py:1122(find_class)
#        33    0.000    0.000    0.000    0.000 pickle.py:1129(load_reduce)
#        84    0.000    0.000    0.000    0.000 pickle.py:1150(load_get)
#       225    0.000    0.000    0.000    0.000 pickle.py:1164(load_put)
#        12    0.000    0.000    0.000    0.000 pickle.py:1193(load_setitem)
#        33    0.000    0.000    0.000    0.000 pickle.py:1211(load_build)
#       120    0.000    0.000    0.000    0.000 pickle.py:1250(load_mark)
#         3    0.000    0.000    0.000    0.000 pickle.py:1254(load_stop)
#         3    0.000    0.000    0.004    0.001 pickle.py:1380(loads)
#         3    0.000    0.000    0.000    0.000 pickle.py:829(__init__)
#         3    0.000    0.000    0.000    0.000 pickle.py:83(__init__)
#         3    0.001    0.000    0.004    0.001 pickle.py:845(load)
#       120    0.000    0.000    0.000    0.000 pickle.py:870(marker)
#        21    0.000    0.000    0.000    0.000 pickle.py:899(load_none)
#       171    0.000    0.000    0.000    0.000 pickle.py:911(load_int)
#         3    0.000    0.000    0.000    0.000 pickle.py:953(load_float)
#        51    0.000    0.000    0.001    0.000 pickle.py:961(load_string)
#       117    0.000    0.000    0.000    0.000 pickle.py:993(load_tuple)
#        15    0.000    0.000    0.000    0.000 posixpath.py:51(normcase)
#        27    0.000    0.000    0.000    0.000 py3k.py:61(isfileobj)
#        28    0.000    0.000    0.000    0.000 series.py:1021(values)
#        22    0.000    0.000    0.002    0.000 series.py:126(__init__)
#         8    0.000    0.000    0.153    0.019 series.py:1926(map)
#         6    0.000    0.000    0.001    0.000 series.py:229(from_array)
#        10    0.000    0.000    0.000    0.000 series.py:239(_constructor)
#        19    0.000    0.000    0.001    0.000 series.py:2490(_sanitize_array)
#        19    0.000    0.000    0.000    0.000 series.py:2503(_try_cast)
#        22    0.000    0.000    0.000    0.000 series.py:254(_set_axis)
#        22    0.000    0.000    0.000    0.000 series.py:276(_set_subtyp)
#        44    0.000    0.000    0.000    0.000 series.py:302(dtype)
#         6    0.000    0.000    0.000    0.000 series.py:348(__len__)
#         2    0.000    0.000    0.000    0.000 series.py:984(__iter__)
#      4254    0.030    0.000    0.046    0.000 shape_base.py:60(atleast_2d)
#      4254    0.015    0.000    0.033    0.000 shape_base.py:8(atleast_1d)
#         3    0.000    0.000    0.000    0.000 stat.py:24(S_IFMT)
#         3    0.000    0.000    0.000    0.000 stat.py:49(S_ISREG)
#        27    0.001    0.000    0.003    0.000 transformer.py:104(__init__)
#   1176/27    0.002    0.000    0.011    0.000 transformer.py:1077(com_binary)
#        27    0.000    0.000    0.011    0.000 transformer.py:120(transform)
#        27    0.000    0.000    0.010    0.000 transformer.py:1211(com_dictorsetmaker)
#        27    0.000    0.000    0.012    0.000 transformer.py:130(parseexpr)
#        27    0.000    0.000    0.011    0.000 transformer.py:145(compile_node)
#        27    0.000    0.000    0.011    0.000 transformer.py:191(eval_input)
#        27    0.000    0.000    0.015    0.001 transformer.py:49(parse)
#     51/27    0.000    0.000    0.011    0.000 transformer.py:574(testlist)
#        24    0.000    0.000    0.002    0.000 transformer.py:584(testlist_comp)
#    225/27    0.000    0.000    0.011    0.000 transformer.py:592(test)
#    225/27    0.000    0.000    0.011    0.000 transformer.py:606(or_test)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:613(and_test)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:617(not_test)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:624(comparison)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:657(expr)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:661(xor_expr)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:665(and_expr)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:669(shift_expr)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:682(arith_expr)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:694(term)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:712(factor)
#     48/24    0.000    0.000    0.000    0.000 transformer.py:72(extractLineNo)
#    225/27    0.001    0.000    0.010    0.000 transformer.py:725(power)
#    225/27    0.000    0.000    0.010    0.000 transformer.py:738(atom)
#        27    0.000    0.000    0.002    0.000 transformer.py:741(atom_lpar)
#        27    0.000    0.000    0.010    0.000 transformer.py:751(atom_lbrace)
#        36    0.000    0.000    0.001    0.000 transformer.py:759(atom_number)
#       108    0.000    0.000    0.002    0.000 transformer.py:764(decode_literal)
#       108    0.000    0.000    0.002    0.000 transformer.py:775(atom_string)
#        27    0.000    0.000    0.000    0.000 transformer.py:781(atom_name)
#      1413    0.000    0.000    0.000    0.000 transformer.py:797(lookup_node)
#   1788/27    0.001    0.000    0.011    0.000 transformer.py:800(com_node)
#         1    0.000    0.000    7.079    7.079 turntable.py:27(evaluate)
#         5    0.000    0.000    0.005    0.001 turntable.py:41(get_path)
#         3    0.000    0.000    0.295    0.098 turntable.py:51(get_match_fun)
#         3    0.000    0.000    6.623    2.208 turntable.py:60(<dictcomp>)
#         4    0.000    0.000    0.139    0.035 turntable.py:63(get_correct)
#     10531    0.026    0.000    0.099    0.000 turntable.py:65(gt_int)
#     10531    0.013    0.000    0.025    0.000 turntable.py:66(pos_int)
#        60    0.015    0.000    0.138    0.002 turntable.py:67(count)
#         4    0.000    0.000    0.014    0.004 turntable.py:70(get_total)
#        60    0.006    0.000    0.014    0.000 turntable.py:72(count)
#        15    0.003    0.000    0.005    0.000 turntable_ground_truth.pyx:126(get_turntable_path)
#        15    0.000    0.000    0.000    0.000 turntable_ground_truth.pyx:240(get_image_set)
#         2    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#        27    0.000    0.000    0.000    0.000 utils.py:1008(visitName)
#        27    0.000    0.000    0.016    0.001 utils.py:1072(safe_eval)
#    252/27    0.000    0.000    0.001    0.000 utils.py:977(visit)
#        27    0.000    0.000    0.001    0.000 utils.py:986(visitExpression)
#       144    0.000    0.000    0.000    0.000 utils.py:990(visitConst)
#        27    0.000    0.000    0.001    0.000 utils.py:993(visitDict)
#        27    0.000    0.000    0.000    0.000 utils.py:996(visitTuple)
#      4254    0.029    0.000    0.086    0.000 validation.py:23(_assert_all_finite)
#      4254    0.021    0.000    0.185    0.000 validation.py:86(array2d)
#        27    0.000    0.000    0.000    0.000 warnings.py:318(__init__)
#        27    0.000    0.000    0.000    0.000 warnings.py:339(__enter__)
#        27    0.000    0.000    0.000    0.000 warnings.py:355(__exit__)
#        27    0.000    0.000    0.000    0.000 warnings.py:74(simplefilter)
#         6    0.000    0.000    0.000    0.000 zipfile.py:1247(__del__)
#        12    0.000    0.000    0.000    0.000 zipfile.py:1251(close)
#         6    0.000    0.000    0.000    0.000 zipfile.py:158(_EndRecData64)
#         6    0.000    0.000    0.000    0.000 zipfile.py:201(_EndRecData)
#        27    0.000    0.000    0.000    0.000 zipfile.py:287(__init__)
#        27    0.000    0.000    0.000    0.000 zipfile.py:377(_decodeFilename)
#        27    0.000    0.000    0.000    0.000 zipfile.py:383(_decodeExtra)
#        54    0.000    0.000    0.000    0.000 zipfile.py:515(__init__)
#       138    0.000    0.000    0.004    0.000 zipfile.py:621(read)
#        72    0.000    0.000    0.002    0.000 zipfile.py:639(_update_crc)
#       138    0.001    0.000    0.003    0.000 zipfile.py:649(read1)
#        54    0.000    0.000    0.000    0.000 zipfile.py:701(close)
#         6    0.000    0.000    0.001    0.000 zipfile.py:726(__init__)
#         6    0.000    0.000    0.001    0.000 zipfile.py:803(_RealGetContents)
#         6    0.000    0.000    0.000    0.000 zipfile.py:872(namelist)
#        54    0.000    0.000    0.000    0.000 zipfile.py:904(getinfo)
#        54    0.000    0.000    0.001    0.000 zipfile.py:937(open)
#         6    0.036    0.006    0.036    0.006 {PIL._imaging.fill}
#         6    0.000    0.000    0.000    0.000 {PIL._imaging.raw_decoder}
#         3    0.000    0.000    0.000    0.000 {PIL._imaging.raw_encoder}
#        21    0.000    0.000    0.000    0.000 {__import__}
#         2    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#         3    0.000    0.000    0.000    0.000 {_hashlib.new}
#       120    0.000    0.000    0.000    0.000 {_struct.unpack}
#         6    0.000    0.000    0.000    0.000 {_weakref.proxy}
#         2    0.000    0.000    0.000    0.000 {all}
#         7    0.000    0.000    0.000    0.000 {any}
#         9    0.000    0.000    0.000    0.000 {cStringIO.StringIO}
#         2    0.000    0.000    0.000    0.000 {callable}
#        27    0.000    0.000    0.000    0.000 {chr}
#       174    0.000    0.000    0.000    0.000 {cv2.SIFT}
#         3    0.103    0.034    0.103    0.034 {cv2.imread}
#       144    0.002    0.000    0.002    0.000 {eval}
#         3    0.000    0.000    0.158    0.053 {fastmatch.match}
#        54    0.000    0.000    0.000    0.000 {function close at 0x7fc1941baed8}
#      2192    0.000    0.000    0.000    0.000 {getattr}
#      2377    0.001    0.000    0.001    0.000 {hasattr}
#        12    0.000    0.000    0.000    0.000 {hash}
#      5229    0.006    0.000    0.006    0.000 {isinstance}
#       264    0.000    0.000    0.000    0.000 {issubclass}
#      10/8    0.000    0.000    0.000    0.000 {iter}
# 37471/37461    0.004    0.000    0.004    0.000 {len}
# 78396/78366    0.074    0.000    0.369    0.000 {map}
#        81    0.000    0.000    0.000    0.000 {max}
#         9    0.000    0.000    0.000    0.000 {method '__setstate__' of 'numpy.dtype' objects}
#        18    0.000    0.000    0.000    0.000 {method '__setstate__' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method '__setstate__' of 'sklearn.neighbors.ball_tree.BinaryTree' objects}
#         3    0.000    0.000    0.000    0.000 {method '__setstate__' of 'sklearn.neighbors.dist_metrics.DistanceMetric' objects}
#        29    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#      9245    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'close' of 'file' objects}
#        12    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         6    0.037    0.006    0.037    0.006 {method 'decode' of 'ImagingDecoder' objects}
#        53    0.001    0.000    0.001    0.000 {method 'decode' of 'str' objects}
#       174    2.119    0.012    2.119    0.012 {method 'detectAndCompute' of 'cv2.Feature2D' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         6    0.000    0.000    0.000    0.000 {method 'encode' of 'ImagingEncoder' objects}
#        78    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        27    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#     21125    0.018    0.000    0.018    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas.index.IndexEngine' objects}
#        27    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        29    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'itervalues' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      3555    0.001    0.000    0.001    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        15    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        93    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        13    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1005    0.000    0.000    0.000    0.000 {method 'read' of 'cStringIO.StringI' objects}
#       204    0.001    0.000    0.001    0.000 {method 'read' of 'file' objects}
#       576    0.000    0.000    0.000    0.000 {method 'readline' of 'cStringIO.StringI' objects}
#      4328    0.047    0.000    0.047    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         6    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#      4254    0.010    0.000    0.010    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         3    0.001    0.000    0.001    0.000 {method 'resize' of 'ImagingCore' objects}
#        84    0.000    0.000    0.000    0.000 {method 'seek' of 'file' objects}
#         6    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingDecoder' objects}
#         3    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#       106    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         3    0.036    0.012    0.036    0.012 {method 'stretch' of 'ImagingCore' objects}
#      4258    0.004    0.000    0.057    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'tell' of 'file' objects}
#        61    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       174    0.000    0.000    0.000    0.000 {min}
#        18    0.000    0.000    0.000    0.000 {numpy.core.multiarray._reconstruct}
#         3    0.000    0.000    0.000    0.000 {numpy.core.multiarray.arange}
#     17117    0.042    0.000    0.042    0.000 {numpy.core.multiarray.array}
#     25549    0.069    0.000    0.069    0.000 {numpy.core.multiarray.copyto}
#     25582    0.046    0.000    0.046    0.000 {numpy.core.multiarray.empty}
#        30    0.000    0.000    0.000    0.000 {numpy.core.multiarray.frombuffer}
#         6    0.000    0.000    0.000    0.000 {open}
#         2    0.000    0.000    0.000    0.000 {operator.truediv}
#         2    0.000    0.000    0.000    0.000 {pandas.algos.ensure_platform_int}
#        12    0.000    0.000    0.000    0.000 {pandas.lib.checknull}
#         3    0.000    0.000    0.000    0.000 {pandas.lib.fast_multiget}
#         1    0.000    0.000    0.000    0.000 {pandas.lib.fast_unique_multiple_list}
#        30    0.000    0.000    0.000    0.000 {pandas.lib.infer_dtype}
#         3    0.000    0.000    0.000    0.000 {pandas.lib.ismember}
#        14    0.000    0.000    0.000    0.000 {pandas.lib.isscalar}
#         4    0.000    0.000    0.000    0.000 {pandas.lib.list_to_object_array}
#         8    0.000    0.000    0.153    0.019 {pandas.lib.map_infer}
#         2    0.000    0.000    0.048    0.024 {pandas.lib.reduce}
#        27    0.000    0.000    0.000    0.000 {parser.expr}
#        27    0.000    0.000    0.000    0.000 {parser.st2tuple}
#         2    0.000    0.000    0.000    0.000 {posix.getpid}
#         3    0.000    0.000    0.000    0.000 {posix.stat}
#       982    0.000    0.000    0.000    0.000 {range}
#         3    0.000    0.000    0.000    0.000 {sklearn.neighbors.ball_tree.newObj}
#         3    0.000    0.000    0.000    0.000 {sklearn.neighbors.dist_metrics.newObj}
#        30    0.000    0.000    0.000    0.000 {sorted}
#       123    0.001    0.000    0.001    0.000 {sum}
#         2    0.000    0.000    0.000    0.000 {time.time}
#        15    0.000    0.000    0.005    0.000 {turntable_ground_truth.get_turntable_path}
#       126    0.002    0.000    0.002    0.000 {zlib.crc32}

# %%
options = {"evaluate_verbose" : True,
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
            "grid_margin" : 40,
            "radius" : 75,
            "thumb_size" : (200, 200)}
results = turntable.evaluate(fastmatch.match, 
                             (0, 25), 
                             "FlowerLamp", 
                             numpy.linspace(0.5, 1.2, 15), 
                             ground_truth = flowerlamp_gt, 
                             options = options)
print("Tau:\t   %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:   %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t   %s" % map(lambda n : "%4i" % n, results["total"]))
print("Precision: %s" % map(lambda n : "%.2f" % n, results["precision"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	   ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:   ['   2', '   3', '   4', '   5', '   7', '   9', '  14', '  17', '  23', '  39', '  52', '  58', '  75', '  87', '  95']
# Total:	   ['   4', '   8', '   9', '  10', '  25', '  46', '  64', '  83', ' 133', ' 267', ' 473', ' 697', ' 961', '1229', '1786']
# Precision: ['0.50', '0.38', '0.44', '0.50', '0.28', '0.20', '0.22', '0.20', '0.17', '0.15', '0.11', '0.08', '0.08', '0.07', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
            "grid_margin" : 40,
            "radius" : 75,
            "thumb_size" : (200, 200)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   4', '   7', '  15', '  19', '  25', '  45', '  62', '  71', '  87', ' 107', ' 118']
# Total:	  ['   4', '  10', '  13', '  19', '  36', '  61', '  82', ' 110', ' 166', ' 357', ' 597', ' 912', '1248', '1646', '2472']
# Accuracy: ['0.25', '0.30', '0.23', '0.16', '0.11', '0.11', '0.18', '0.17', '0.15', '0.13', '0.10', '0.08', '0.07', '0.07', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 67,
            "thumb_size" : (200, 200)}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-71b368abd2cd> in <module>()
#       6             "radius" : 67,
#       7             "thumb_size" : (200, 200)}
# ----> 8 results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
#       9 accu = numpy.array(results["accuracy"], dtype=numpy.float)
#      10 print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
#
# /home/arnfred/Experiments/fastmatch/turntable.py in evaluate(match_fun, angles, object_type, thresholds, ground_truth, options)
#      66
#      67     # For each set of matches count correct matches
# ---> 68     correct = numpy.array([get_correct(ms, img) for img, ms in matches])
#      69     total = numpy.array([get_total(ms, img) for img, ms in matches])
#      70     accuracy = correct / numpy.array(total, dtype=numpy.float)
#
# ValueError: too many values to unpack

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 60}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   5', '   7', '  12', '  16', '  20', '  43', '  57', '  66', '  88', ' 110', ' 125']
# Total:	  ['   8', '  14', '  18', '  27', '  39', '  60', '  78', ' 106', ' 140', ' 313', ' 508', ' 815', '1322', '1756', '2305']
# Accuracy: ['0.12', '0.21', '0.17', '0.11', '0.13', '0.12', '0.15', '0.15', '0.14', '0.14', '0.11', '0.08', '0.07', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 60}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   5', '   7', '  12', '  16', '  20', '  43', '  57', '  66', '  88', ' 110', ' 125']
# Total:	  ['   8', '  14', '  18', '  27', '  39', '  60', '  78', ' 106', ' 140', ' 313', ' 508', ' 815', '1322', '1756', '2305']
# Accuracy: ['0.12', '0.21', '0.17', '0.11', '0.13', '0.12', '0.15', '0.15', '0.14', '0.14', '0.11', '0.08', '0.07', '0.06', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 45}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   5', '   6', '   9', '  13', '  14', '  22', '  30', '  35', '  46', '  57', ' 111']
# Total:	  ['   8', '  13', '  15', '  23', '  32', '  41', '  49', '  69', '  91', ' 175', ' 282', ' 395', ' 655', ' 917', '1698']
# Accuracy: ['0.12', '0.23', '0.20', '0.13', '0.16', '0.15', '0.18', '0.19', '0.15', '0.13', '0.11', '0.09', '0.07', '0.06', '0.07']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 40}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   5', '   6', '   8', '  12', '  13', '  22', '  28', '  31', '  41', '  52', '  59']
# Total:	  ['   8', '  11', '  12', '  17', '  22', '  32', '  41', '  54', '  72', ' 142', ' 220', ' 327', ' 493', ' 756', '1087']
# Accuracy: ['0.12', '0.27', '0.25', '0.18', '0.23', '0.19', '0.20', '0.22', '0.18', '0.15', '0.13', '0.09', '0.08', '0.07', '0.05']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 35}
results = turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 15), options = options)
accu = numpy.array(results["accuracy"], dtype=numpy.float)
print("Tau:\t  %s" % map(lambda n : "%.2f" % n, numpy.linspace(0.5, 1.2, 15)))
print("Correct:  %s" % map(lambda n : "%4i" % n, results["correct"]))
print("Total:\t  %s" % map(lambda n : "%4i" % n, results["total"]))
print("Accuracy: %s" % map(lambda n : "%.2f" % n, results["accuracy"]))
# Out:
# matching
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-000_08-35-08_0.JPG
# ../../Images/turntable//imageset_1/FlowerLamp/Bottom/img_1-025_08-36-34_0.JPG
# Tau:	  ['0.50', '0.55', '0.60', '0.65', '0.70', '0.75', '0.80', '0.85', '0.90', '0.95', '1.00', '1.05', '1.10', '1.15', '1.20']
# Correct:  ['   1', '   3', '   3', '   3', '   4', '   5', '   7', '  10', '   9', '  15', '  20', '  25', '  31', '  38', '  50']
# Total:	  ['   7', '  10', '  10', '  14', '  17', '  25', '  32', '  40', '  56', ' 105', ' 165', ' 240', ' 300', ' 484', ' 705']
# Accuracy: ['0.14', '0.30', '0.30', '0.21', '0.24', '0.20', '0.22', '0.25', '0.16', '0.14', '0.12', '0.10', '0.10', '0.08', '0.07']

# %%
options = {"evaluate_verbose" : True, 
           "distance_threshold" : 5, 
           "thumb_strategy" : lambda n : min(n*1.2, 0.9),
           "grid_size" : (75, 75),
           "grid_margin" : 40,
            "radius" : 30}
turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options)
#profile.run('turntable.evaluate(fastmatch.match, (0, 25), "FlowerLamp", numpy.linspace(0.5, 1.2, 20), options)')
# Out:
# {'accuracy': array([ 0.        ,  0.16666667,  0.15      ,  0.13043478,  0.09677419,
#          0.07692308,  0.06382979,  0.05769231,  0.07936508,  0.12195122,
#          0.11764706,  0.15263158,  0.14956012,  0.12698413,  0.11229135,
#          0.09453303,  0.07594937,  0.06696147,  0.05642317,  0.05196982]),
#  'correct': array([  0,   3,   3,   3,   3,   3,   3,   3,   5,  10,  12,  29,  51,
#          64,  74,  83,  90, 106, 112, 124]),
#  'total': array([  11,   18,   20,   23,   31,   39,   47,   52,   63,   82,  102,
#          190,  341,  504,  659,  878, 1185, 1583, 1985, 2386])}
